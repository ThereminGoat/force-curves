# %%
import sys
from importlib import reload
import os
import pandas as pd

# %%
from data_process import DataProcess
reload(sys.modules['data_process'])
from data_process import DataProcess

dd = DataProcess()
_dic = dd.main()

# %%
_dic['Downstroke']
# Out:
#          2     11   Switch_Name        Mode
# 0     -0.1  0.000  Aflion Blush  Downstroke
# 1      9.3  0.010  Aflion Blush  Downstroke
# 2     17.9  0.020  Aflion Blush  Downstroke
# 3     23.6  0.025  Aflion Blush  Downstroke
# 4     28.0  0.030  Aflion Blush  Downstroke
# ..     ...    ...           ...         ...
# 956   90.1  3.210  Aflion Blush  Downstroke
# 957   92.4  3.215  Aflion Blush  Downstroke
# 958   94.8  3.215  Aflion Blush  Downstroke
# 959   97.5  3.220  Aflion Blush  Downstroke
# 960  100.2  3.220  Aflion Blush  Downstroke
#
# [961 rows x 4 columns]

# %%
df = pd.DataFrame()
dict = pd.read_excel(file_paths[1], header=None, usecols='C,L', skiprows=5, sheet_name=['Downstroke', 'Upstroke'])

_df = pd.read_excel(file_paths[3], header=None, usecols='B', skiprows=1, sheet_name=['DataTable'])
switch_name = _df['DataTable'].iloc[0, 0]



rnm_col = {2: 'Force', 11: 'Displacement'}
for kk, df in dict.items():
    df.rename(columns=rnm_col, inplace=True)
# df['Down_displ'] = dict['Downstroke'][11]
# df['Down_force'] = dict['Downstroke'][2]
# df['Up_displ'] = dict['Upstroke'][11][:]
# df['UP_force'] = dict['Upstroke'][2][:]

# %%
nam
# Out:
# {'DataTable':                          1
#  0  Aflion Black and Orange
#  1     Switch Type: Tactile
#  2        Total Stem Travel
#  3               Peak Force
#  4         Bottom Out Force
#  5     # of Upstroke Points
#  6   # of Downstroke Points}

# %%
dict['RawData']
# Out:
#       Force  Displacement
# 0       0.0          -0.4
# 1       0.1          -0.4
# 2      -0.1          -0.4
# 3      -0.1          -0.4
# 4       0.0          -0.4
# ...     ...           ...
# 5231    NaN          -0.4
# 5232    NaN          -0.4
# 5233    NaN          -0.4
# 5234    NaN          -0.4
# 5235    NaN          -0.4
#
# [5236 rows x 2 columns]

# %%
dict['Downstroke']
# Out:
#        2      11
# 0     0.0  0.000
# 1     5.1  0.010
# 2    12.3  0.015
# 3    19.7  0.025
# 4    26.6  0.030
# ..    ...    ...
# 762  88.6  3.205
# 763  90.6  3.210
# 764  93.1  3.210
# 765  96.4  3.215
# 766  99.4  3.220
#
# [767 rows x 2 columns]

# %%
df = pd.DataFrame()
df[]

# %%
a['Upstroke']
# Out:
#        2      11
# 0    99.1  3.225
# 1    98.3  3.220
# 2    97.4  3.220
# 3    95.2  3.220
# 4    93.1  3.215
# ..    ...    ...
# 830   1.9  0.010
# 831   0.1  0.005
# 832   0.1 -0.005
# 833   0.1 -0.010
# 834   0.0 -0.015
#
# [835 rows x 2 columns]

# %%
pd.read_excel(file_paths[4], header=None, usecols='C,L', skiprows=5, sheet_name='Downstroke')
# Out:
#         2      11
# 0     -0.1  0.000
# 1      0.1  0.010
# 2      3.8  0.015
# 3     10.2  0.020
# 4     16.3  0.030
# ..     ...    ...
# 714   85.7  3.255
# 715   89.3  3.260
# 716   92.9  3.260
# 717   96.7  3.265
# 718  100.1  3.270
#
# [719 rows x 2 columns]

# %%
list(os.walk('../'))[0]
# Out:
# ('../',
#  ['.git',
#   '.idea',
#   '0_data_process',
#   'A Switch With No Good Name',
#   'Aflion Black and Orange',
#   'Aflion Blue Sky',
#   'Aflion Blush',
#   'Aflion Holy Panda',
#   'Aflion Iceberg Rainbow Blue',
#   'Aflion Tropical Waters',
#   'Agile Moon',
#   'Ajazz AS Coral Pink',
#   'Ajazz AS Foggy Mountain Green',
#   'Ajazz AS Royal Yellow',
#   'Ajazz AS Sky Blue',
#   'Ajazz Brown (Clear Top, Black Bottom)',
#   'Ajazz Doyu Orange',
#   'Ajazz Doyu White',
#   'Ajazz Purple',
#   'Ajazz x Huano Banana',
#   'Ajazz x Huano Peach',
#   'Akko Air',
#   'Akko Blue V2',
#   'Akko Crystal',
#   'Akko Crystal Blue',
#   'Akko Crystal Silver',
#   'Akko Crystal Wine Red',
#   'Akko CS Jelly Black',
#   'Akko CS Jelly Blue',
#   'Akko CS Jelly Pink',
#   'Akko CS Jelly Purple',
#   'Akko CS Jelly White',
#   'Akko CS Lavender Purple',
#   'Akko CS Radiant Red',
#   'Akko CS Sponge',
#   'Akko CS Starfish',
#   'Akko CS Vintage White',
#   'Akko CS Wine White',
# ...

# %%
for x in os.walk('../'):
    print(x[0])
# Out:
# ../
# ../.git
# ../.git\hooks
# ../.git\info
# ../.git\logs
# ../.git\logs\refs
# ../.git\logs\refs\heads
# ../.git\logs\refs\remotes
# ../.git\logs\refs\remotes\origin
# ../.git\objects
# ../.git\objects\info
# ../.git\objects\pack
# ../.git\refs
# ../.git\refs\heads
# ../.git\refs\remotes
# ../.git\refs\remotes\origin
# ../.git\refs\tags
# ../.idea
# ../.idea\inspectionProfiles
# ../0_data_process
# ../A Switch With No Good Name
# ../Aflion Black and Orange
# ../Aflion Blue Sky
# ../Aflion Blush
# ../Aflion Holy Panda
# ../Aflion Iceberg Rainbow Blue
# ../Aflion Tropical Waters
# ../Agile Moon
# ../Ajazz AS Coral Pink
# ../Ajazz AS Foggy Mountain Green
# ../Ajazz AS Royal Yellow
# ../Ajazz AS Sky Blue
# ../Ajazz Brown (Clear Top, Black Bottom)
# ../Ajazz Doyu Orange
# ../Ajazz Doyu White
# ../Ajazz Purple
# ../Ajazz x Huano Banana
# ../Ajazz x Huano Peach
# ../Akko Air
# ../Akko Blue V2
# ../Akko Crystal
# ../Akko Crystal Blue
# ../Akko Crystal Silver
# ../Akko Crystal Wine Red
# ...
