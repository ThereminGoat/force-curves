# %%
import sys
from importlib import reload
import os

# %%
from data_process import DataProcess
reload(sys.modules['data_process'])
from data_process import DataProcess

dd = DataProcess()
dd.main()
# Out:
# ['A Switch With No Good Name Raw Data CSV.csv']
# ['Aflion Black and Orange Raw Data CSV.csv']
# ['Aflion Blue Sky Raw Data CSV.csv']
# ['Aflion Blush Raw Data CSV.csv']
# ['Aflion Holy Panda Raw Data CSV.csv']
# ['Aflion Iceberg Rainbow Blue Raw Data CSV.csv']
# ['Aflion Tropical Waters Raw Data CSV.csv']
# ['Agile Moon Raw Data CSV.csv']
# ['Ajazz AS Coral Pink Raw Data CSV.csv']
# ['Ajazz AS Foggy Mountain Green Raw Data CSV.csv']
# ['Ajazz AS Royal Yellow Raw Data CSV.csv']
# ['Ajazz AS Sky Blue Raw Data CSV.csv']
# ['Ajazz Brown_Black Bottom Raw Data CSV.csv']
# ['Ajazz Doyu Orange Raw Data CSV.csv']
# ['Ajazz Doyu White Raw Data CSV.csv']
# ['Ajazz Purple Raw Data CSV.csv']
# ['Ajazz x Huano Banana Raw Data CSV.csv']
# ['Ajazz x Huano Peach Raw Data CSV.csv']
# ['Akko Air Raw Data CSV.csv']
# ['Akko Blue V2 Raw Data CSV.csv']
# ['Akko Crystal Raw Data CSV.csv']
# ['Akko Crystal Blue Raw Data CSV.csv']
# ['Akko Crystal Silver Raw Data CSV.csv']
# ['Akko Crystal Wine Red Raw Data CSV.csv']
# ['Akko CS Jelly Black Raw Data CSV.csv']
# ['Akko CS Jelly Blue Raw Data CSV.csv']
# ['Akko CS Jelly Pink Raw Data CSV.csv']
# ['Akko CS Jelly Purple Raw Data CSV.csv']
# ['Akko CS Jelly White Raw Data CSV.csv']
# ['Akko CS Lavender Purple Raw Data CSV.csv']
# ['Akko CS Radiant Red Raw Data CSV.csv']
# ['Akko CS Sponge Raw Data CSV.csv']
# ['Akko CS Starfish Raw Data CSV.csv']
# ['Akko CS Vintage White Raw Data CSV.csv']
# ['Akko CS Wine White Raw Data CSV.csv']
# ['Akko Orange V1 Raw Data CSV.csv']
# ['Akko POM Brown Raw Data CSV.csv']
# ['Akko POM Pink Raw Data CSV.csv']
# ['Akko POM Silver Raw Data CSV.csv']
# ['Akko Snow Blue Grey Raw Data CSV.csv']
# ['Akko V3 Cream Blue Raw Data CSV.csv']
# ['Akko V3 Cream Yellow Raw Data CSV.csv']
# ['Akko Wine Red Raw Data CSV.csv']
# ['All Clack Raw Data CSV.csv']
# ['AngryMiao Cyberswitch Raw Data CSV.csv']
# ['Aristotle White Raw Data CSV.csv']
# ['Asus Rog NX Blue Raw Data CSV.csv']
# ['Asus Rog NX Brown Raw Data CSV.csv']
# ['Asus Rog NX Red Raw Data CSV.csv']
# ['BBN (Tactile) Raw Data CSV.csv']
# ['BBN Linear Raw Data CSV.csv']
# ['Betty Raw Data CSV.csv']
# ['Bingsu POM Raw Data CSV.csv']
# ['Black Geon Switch Raw Data CSV.csv']
# ['Blaeck Raw Data CSV.csv']
# ['Bluejay Raw Data CSV.csv']
# ['Bobagum (62g) Raw Data CSV.csv']
# ['Bolsa Namazu Raw Data CSV.csv']
# ['Brazilian Iron Raw Data CSV.csv']
# []
# []
# ['BSUN Crystal White Raw Data CSV.csv']
# ['BSUN Dragon Fruit Panda V2 Raw Data CSV.csv']
# ['BSUN Dustproof Blue Raw Data CSV.csv']
# ['BSUN Ginseng Fruit Raw Data CSV.csv']
# ['BSUN Light Switch Raw Data CSV.csv']
# ['BSUN Lychee Black Raw Data CSV.csv']
# ['BSUN Lychee Red Raw Data CSV.csv']
# ['BSUN Peach Pride Raw Data CSV.csv']
# ['BSUN Pikachu Raw Data CSV.csv']
# ['BSUN Polar Panda V2 Raw Data CSV.csv']
# ['BSUN POM Panda Black Raw Data CSV.csv']
# ['BSUN POM Panda Red Raw Data CSV.csv']
# ['BSUN Racoon Panda V2 Raw Data CSV.csv']
# ['BSUN Smoky Pink Tactile Raw Data CSV.csv']
# ['BSUN Yellow (Clear_White) Raw Data CSV.csv']
# ['C3 Equalz Tangerine V2 (62g) Raw Data CSV.csv']
# ['C3 Kiwi Raw Data CSV.csv']
# ['Ca Phe Sua Da Raw Data CSV.csv']
# ['Cardinal Raw Data CSV.csv']
# ['CHAOSERA Klein Raw Data CSV.csv']
# ['Cherry Blossom Raw Data CSV.csv']
# ['Cherry Hirose Clear Raw Data CSV.csv']
# ['Cherry Hirose Orange Raw Data CSV.csv']
# ['Cherry MX New Nixie (Black Clear-Top) Raw Data CSV.csv']
# ['Cherry MX Black Raw Data CSV.csv']
# ['Cherry MX Blue Raw Data CSV.csv']
# ['Cherry MX Brown Raw Data CSV.csv']
# ['Cherry MX Clear Raw Data CSV.csv']
# ['Cherry MX Green Raw Data CSV.csv']
# ['Cherry MX Hyperglide Black (3 Pin) Raw Data CSV.csv']
# ['Cherry MX Hyperglide Black (5 Pin) Raw Data CSV.csv']
# ['Cherry MX Hyperglide Brown Raw Data CSV.csv']
# ['Cherry MX Jailhouse Blue Raw Data CSV.csv']
# ['Cherry MX Linear Grey Raw Data CSV.csv']
# ['Cherry MX Lock (Locking) Raw Data CSV.csv', 'Cherry MX Lock (Unlocking) Raw Data CSV.csv']
# ['Cherry MX Red Raw Data CSV.csv']
# ['Cherry MX Tactile Grey Raw Data CSV.csv']
# ['Cherry MX White Raw Data CSV.csv']
# ['Cherry MX_M8 Black Adapter Raw Data CSV.csv']
# ['Cherry MX_M8 White Adapter Raw Data CSV.csv']
# ['Cherry Nixdorf Black Raw Data CSV.csv']
# ['Cherry Nixdorf White Raw Data CSV.csv']
# ['Chocolate Toffee Linear Raw Data CSV.csv']
# ['Chosfox x JWICK Voyager Raw Data CSV.csv']
# ['CIY Evolution Red Raw Data CSV.csv']
# ['CK x Haimu Pastel Lemon Raw Data CSV.csv']
# ['CK x Haimu Pastel Mint Raw Data CSV.csv']
# ['CK x Haimu Pastel Peach Raw Data CSV.csv']
# ['Clickiez 40g Clicky 2 Raw Data CSV.csv', 'Clickiez 40g Clicky 3 Raw Data CSV.csv', 'Clickiez 40g Clicky Raw Data CSV.csv']
# ['Clickiez 40g Linear 2 Raw Data CSV.csv', 'Clickiez 40g Linear 3 Raw Data CSV.csv', 'Clickiez 40g Linear Raw Data CSV.csv']
# ['Clickiez 40g Tactile 2 Raw Data CSV.csv', 'Clickiez 40g Tactile 3 Raw Data CSV.csv', 'Clickiez 40g Tactile Raw Data CSV.csv']
# ['Clickiez 75g Clicky 2 Raw Data CSV.csv', 'Clickiez 75g Clicky 3 Raw Data CSV.csv', 'Clickiez 75g Clicky Raw Data CSV.csv']
# ['Clickiez 75g Linear 2 Raw Data CSV.csv', 'Clickiez 75g Linear 3 Raw Data CSV.csv', 'Clickiez 75g Linear Raw Data CSV.csv']
# ['Clickiez 75g Tactile 2 Raw Data CSV.csv', 'Clickiez 75g Tactile 3 Raw Data CSV.csv', 'Clickiez 75g Tactile Raw Data CSV.csv']
# ['Commute Raw Data CSV.csv']
# ["Cookies n' Cream Raw Data CSV.csv"]
# ['Corsa Raw Data CSV.csv']
# ['Cotton Candy Raw Data CSV.csv']
# ['Crow Raw Data CSV.csv']
# ['DareU Candy Pink V1 Raw Data CSV.csv']
# ['DareU Sky Blue V3 Raw Data CSV.csv']
# ['DareU Sky V2 Raw Data CSV.csv']
# ['DareU Violet Gold Pro Raw Data CSV.csv']
# ['DareU Violet_Purple Gold V2 Raw Data CSV.csv']
# ['Designer Studio Graphite Gold Raw Data CSV.csv']
# ['Designer Studio Retro Light Blue Raw Data CSV.csv']
# ['Designer Studio Retro Light Green Raw Data CSV.csv']
# ['Designer Studio Retro Light Red Raw Data CSV.csv']
# ['Designer Studio Starry Raw Data CSV.csv']
# ['Designer Studio Taoyao Raw Data CSV.csv']
# ['dk Oni Raw Data CSV.csv']
# ['Doom Tactile Raw Data CSV.csv']
# ['Durock Black Lotus (63.5g) Raw Data CSV.csv']
# ['Durock Black Lotus (80g) Raw Data CSV.csv']
# ['Durock Blush Raw Data CSV.csv']
# ['Durock POM Linear Raw Data CSV.csv']
# ['Durock Shrimp Raw Data CSV.csv']
# ['Emogogo Grey Raw Data CSV.csv']
# ['Emogogo White Raw Data CSV.csv']
# ['EMT V1 Raw Data CSV.csv']
# ['EMT V2 Raw Data CSV.csv']
# ['Epomaker Bluebird Raw Data CSV.csv']
# ['Epomaker Budgreigar Raw Data CSV.csv']
# ['Epomaker Comte Raw Data CSV.csv']
# ['Epomaker Flamingo Raw Data CSV.csv']
# ['Epsilon V2 Raw Data CSV.csv']
# ['Feker Emerald Yellow Raw Data CSV.csv']
# ['Feker Matcha Raw Data CSV.csv']
# ['Feker White Marble Raw Data CSV.csv']
# ['Firstblood Blue Raw Data CSV.csv']
# ['Firstblood Pink Raw Data CSV.csv']
# ['FLCMMK Bauhinia Raw Data CSV.csv']
# ['FLCMMK Box Rosa Pink Raw Data CSV.csv']
# ['FLCMMK Ice Mint Raw Data CSV.csv']
# ['Forgiven Raw Data CSV.csv']
# ['G-Sqaure Black Warrior V2 Raw Data CSV.csv']
# ['G-Square Dreamland Linear Raw Data CSV.csv']
# ['G-Square Dreamland Tactile Raw Data CSV.csv']
# ['G-Square White Warrior Raw Data CSV.csv']
# ['Ganss Lunar Blue Raw Data CSV.csv']
# ['Ganss Lunar Grey Raw Data CSV.csv']
# ['Gateron Azure Dragon V2 Raw Data CSV.csv']
# ['Gateron Baby Kangaroo 2  Raw Data CSV.csv', 'Gateron Baby Kangaroo Raw Data CSV.csv']
# ['Gateron Baby Racoon Raw Data CSV.csv']
# ['Gateron Box Ink Pink Raw Data CSV.csv']
# ['Gateron Camping Raw Data CSV.csv']
# ['Gateron Cap Crystal Blue Raw Data CSV.csv']
# ['Gateron Cap Crystal Brown Raw Data CSV.csv']
# ['Gateron Cap Crystal Red Raw Data CSV.csv']
# ['Gateron Cap Crystal Silent Red Raw Data CSV.csv']
# ['Gateron Cap Crystal Silver Raw Data CSV.csv']
# ['Gateron Cap Crystal Yellow Raw Data CSV.csv']
# ['Gateron CAP Yellow V2 Raw Data CSV.csv']
# ['Gateron CJ Light Blue Raw Data CSV.csv']
# ['Gateron Cream Soda Raw Data CSV.csv']
# ['Gateron FC Raw Data CSV.csv']
# ['Gateron Holy Panda X Raw Data CSV.csv']
# ['Gateron Holy Panda X Prototype Raw Data CSV.csv']
# ['Gateron Kangaroo Ink Raw Data CSV.csv']
# ['Gateron KS9 Pro 2.0 Black Raw Data CSV.csv']
# ['Gateron KS9 Pro 2.0 Blue Raw Data CSV.csv']
# ['Gateron KS9 Pro 2.0 Brown Raw Data CSV.csv']
# ['Gateron KS9 Pro 2.0 Red Raw Data CSV.csv']
# ['Gateron KS9 Pro 2.0 Silver Raw Data CSV.csv']
# ['Gateron KS9 Pro 2.0 White Raw Data CSV.csv']
# ['Gateron KS9 Pro 2.0 Yellow Raw Data CSV.csv']
# ['Gateron Limbo Raw Data CSV.csv']
# ['Gateron Lion Raw Data CSV.csv']
# ['Gateron Mini Raw Data CSV.csv']
# ['Gateron Mink Raw Data CSV.csv']
# ['Gateron Mizu Mink Raw Data CSV.csv']
# ['Gateron North Pole Raw Data CSV.csv']
# ['Gateron Oil King Raw Data CSV.csv']
# ['Gateron Phantom Blue Raw Data CSV.csv']
# ['Gateron Phantom Red Raw Data CSV.csv']
# ['Gateron Root Beer Float 2 Raw Data CSV.csv', 'Gateron Root Beer Float 3 Raw Data CSV.csv', 'Gateron Root Beer Float Raw Data CSV.csv']
# ['Gateron Root Beer Float (New Pin) 2 Raw Data CSV.csv', 'Gateron Root Beer Float (New Pin) 3 Raw Data CSV.csv', 'Gateron Root Beer Float (New Pin) Raw Data CSV.csv']
# ['Gateron Silent Ink V2 Raw Data CSV.csv']
# ['Gateron UHMknown 2 Raw Data CSV.csv', 'Gateron UHMknown 3 Raw Data CSV.csv', 'Gateron UHMknown 4 Raw Data CSV.csv', 'Gateron UHMknown 5 Raw Data CSV.csv', 'Gateron UHMknown Raw Data CSV.csv']
# ['Gateron Unicorn Raw Data CSV.csv']
# ['Gateron Vermillion Bird Raw Data CSV.csv']
# ['Gateron X Raw Data CSV.csv']
# ['Gateron x Swagkeys Pure Berry Raw Data CSV.csv']
# ['Gateron X V2 Raw Data CSV.csv']
# ['Gatistotle Raw Data CSV.csv']
# ['Gazzew Phoenix Final 75g Raw Data CSV.csv']
# ['Gazzew Phoenix V1 75g Raw Data CSV.csv']
# ['Gazzew Phoenix V2 75g Raw Data CSV.csv']
# ['Glorious Fox Raw Data CSV.csv']
# ['GoPolar Yang Raw Data CSV.csv']
# ['GoPolar Yin Raw Data CSV.csv']
# ['Grain Gold Blue Linear Sample Raw Data CSV.csv']
# ['Grain Gold Neon V1 Raw Data CSV.csv']
# ['Grain Gold Neon V2 Raw Data CSV.csv']
# ['Grain Gold Tom Gold Pink Raw Data CSV.csv']
# ['Green Jacket Linear Raw Data CSV.csv']
# ['Green Jacket Tactile Raw Data CSV.csv']
# ['Greetech Black (Clear_White, 3 Pin) Raw Data CSV.csv']
# ['Greetech Blue (Black Housing) Raw Data CSV.csv']
# ['Greetech Blue (Clear_White, 5 Pin) Raw Data CSV.csv']
# ['Gypsophilia 1 Raw Data CSV.csv']
# ['Gypsophilia 2 Raw Data CSV.csv']
# ['Gypsophilia 3 Raw Data CSV.csv']
# ['Gypsophilia 4 Raw Data CSV.csv']
# ['Gypsophilia 5 Raw Data CSV.csv']
# ['Gypsophilia 6 Raw Data CSV.csv']
# ['Hades Raw Data CSV.csv']
# ['Haimu Heartbeat Raw Data CSV.csv']
# ['Haimu Whisper Raw Data CSV.csv']
# ['Haimu x Geon White Raw Data CSV.csv']
# ['Haimu x Geon Yellow Raw Data CSV.csv']
# ['HAPE Orange Raw Data CSV.csv']
# ['HCP Hirose Clear Raw Data CSV.csv']
# ['HiGround x TTC Titan Heart Raw Data CSV.csv']
# ['HK Gaming MS-1 Pro Lake Blue Raw Data CSV.csv']
# ['HK Gaming MS-1 Pro Marlin Blue Raw Data CSV.csv']
# ['HK Gaming MS-1 Pro Sky Blue Raw Data CSV.csv']
# ['Honeycomb Raw Data CSV.csv']
# ['Hoshizora Raw Data CSV.csv']
# ['Huano Dustproof Purple_Hot Pink (Grey Bottom) Raw Data CSV.csv']
# ['Huano Earth Yellow Raw Data CSV.csv']
# ['Huano Hot Pink Raw Data CSV.csv']
# ['Huano Pandora Raw Data CSV.csv']
# ['Huano Pineapple 17000 Actuations Raw Data CSV.csv', 'Huano Pineapple 2 Raw Data CSV.csv', 'Huano Pineapple 3 Raw Data CSV.csv', 'Huano Pineapple 34000 Actuations Raw Data CSV.csv', 'Huano Pineapple Raw Data CSV.csv']
# ['Huano Pink Raw Data CSV.csv']
# ['Huano Purple Raw Data CSV.csv']
# ['Huano Red_Orange Raw Data CSV.csv']
# ['Huano Silver Raw Data CSV.csv']
# ['Huano Spirit Wind Raw Data CSV.csv']
# ['Huano Teal Raw Data CSV.csv']
# ['Huano Turquoise Raw Data CSV.csv']
# ['Husky Raw Data CSV.csv']
# ['HyperX Aqua Raw Data CSV.csv']
# ['HyperX Blue Raw Data CSV.csv']
# ['HyperX Red Raw Data CSV.csv']
# ['In Former Days Raw Data CSV.csv']
# ['Invokeys Black Sesame Raw Data CSV.csv']
# ['Invokeys Blueberry Chiffon HDPE Prototype R1 Raw Data CSV.csv']
# ['Invokeys Blueberry Chiffon Prototype R1 Raw Data CSV.csv']
# ['Invokeys Blueberry Chiffon Prototype R2 Raw Data CSV.csv']
# ['Invokeys Matcha Latte Raw Data CSV.csv']
# ['Invyr Holy Panda Raw Data CSV.csv']
# ['Jerrzi Black Raw Data CSV.csv']
# ['Jerrzi Blue Raw Data CSV.csv']
# ['Jerrzi Brown Raw Data CSV.csv']
# ['Jerrzi Coral Raw Data CSV.csv']
# ['Jerrzi Dustproof Clear Raw Data CSV.csv']
# ['Jerrzi Dustproof Pink Raw Data CSV.csv']
# ['Jerrzi Dustproof White Raw Data CSV.csv']
# ['Jerrzi Dustproof Yellow Raw Data CSV.csv']
# ['Jerrzi Kyria Brown Raw Data CSV.csv']
# ['Jerrzi Kyria Grey Raw Data CSV.csv']
# ['Jerrzi Kyria Pink Raw Data CSV.csv']
# ['Jerrzi Kyria Red Raw Data CSV.csv']
# ['Jerrzi Kyria White Raw Data CSV.csv']
# ['Jerrzi Kyria Yellow Raw Data CSV.csv']
# ['Jerrzi Orange Raw Data CSV.csv']
# ['Jerrzi Red Raw Data CSV.csv']
# ['Jerrzi Seashell Raw Data CSV.csv']
# ['Jerrzi Violet Raw Data CSV.csv']
# ['Jerrzi Yellow Raw Data CSV.csv']
# ['Jixian Blue Raw Data CSV.csv']
# ['JKLP Holy Panda Raw Data CSV.csv']
# ['JWICK Ginger Milk Raw Data CSV.csv']
# ['JWICK Ice White Raw Data CSV.csv']
# ['JWICK Red Raw Data CSV.csv']
# ['JWICK Semi Silent Raw Data CSV.csv']
# ['JWICK T1 Raw Data CSV.csv']
# ['JWICK Taro Raw Data CSV.csv']
# ['JWICK Ultimate Black Raw Data CSV.csv']
# ['JWICK Yellow Raw Data CSV.csv']
# ['JWK Black CV1 Raw Data CSV.csv']
# ['JWK Black CV2 Raw Data CSV.csv']
# ['JWK Blue Lotus Raw Data CSV.csv']
# ['JWK Bluey Raw Data CSV.csv']
# ['JWK CW Raw Data CSV.csv']
# ['JWK DIE FOR ME Raw Data CSV.csv']
# ['JWK F1 Raw Data CSV.csv']
# ['JWK Pink-Jade Raw Data CSV.csv']
# ['Kailh Arctic Fox Raw Data CSV.csv']
# ['Kailh Arctic Fox V2 Raw Data CSV.csv']
# ['Kailh Box Ancient Grey Raw Data CSV.csv']
# ['Kailh Box Jade Raw Data CSV.csv']
# ['Kailh Box Navy Raw Data CSV.csv']
# ['Kailh Box Speed Ultimate Raw Data CSV.csv']
# ['Kailh Box Summer (Zhixia) Raw Data CSV.csv']
# ['Kailh Box V2 Brown Raw Data CSV.csv']
# ['Kailh Box V2 Red Raw Data CSV.csv']
# ['Kailh Box V2 White Raw Data CSV.csv']
# ['Kailh Chinoiserie Delo Raw Data CSV.csv']
# ['Kailh Christmas Tree Raw Data CSV.csv']
# ['Kailh Crystal Burgundy Raw Data CSV.csv']
# ['Kailh Deep Sea Raw Data CSV.csv']
# ['Kailh MX Star Raw Data CSV.csv']
# ['Kailh Pink Unicorn Raw Data CSV.csv']
# ['Kailh Pro Burgundy (PCB Mount) Raw Data CSV.csv']
# ['Kailh Pro Burgundy (Plate Mount) Raw Data CSV.csv']
# ['Kailh Pro Heavy Berry (PCB Mount) Raw Data CSV.csv']
# ['Kailh Pro Heavy Berry (Plate Mount) Raw Data CSV.csv']
# []
# ['Kailh Pro Heavy Plum (Plate Mount) Raw Data CSV.csv']
# ['Kailh Pro Heavy Sage (PCB Mount) Raw Data CSV.csv']
# ['Kailh Pro Heavy Sage (Plate Mount) Raw Data CSV.csv']
# ['Kailh Pro Light Green (PCB Mount) Raw Data CSV.csv']
# ['Kailh Pro Light Green (Plate Mount) Raw Data CSV.csv']
# ['Kailh Pro Midnight Grey Raw Data CSV.csv']
# ['Kailh Pro Midnight Light Yellow Raw Data CSV.csv']
# ['Kailh Pro Purple (PCB Mount) Raw Data CSV.csv']
# ['Kailh Pro Purple (Plate Mount) Raw Data CSV.csv']
# ['Kailh Santa Hat Raw Data CSV.csv']
# ['Kailh Speed Bronze (Plate Mount) Raw Data CSV.csv']
# ['Kailh Speed Copper (PCB Mount) Raw Data CSV.csv']
# ['Kailh Speed Copper (Plate Mount) Raw Data CSV.csv']
# ['Kailh Speed Gold (PCB Mount) Raw Data CSV.csv']
# ['Kailh Speed Gold (Plate Mount) Raw Data CSV.csv']
# ['Kailh Speed Pink Raw Data CSV.csv']
# ['Kailh Speed Silver (PCB Mount) Raw Data CSV.csv']
# ['Kailh Speed Silver (Plate Mount) Raw Data CSV.csv']
# ['Kailh Sunset Tactile Choc Raw Data CSV.csv']
# ['Kailh Super Speed Red Raw Data CSV.csv']
# ['Kailh Super Speed Silver Raw Data CSV.csv']
# ['Kailh White Owl Raw Data CSV.csv']
# ['Kailh x Varmilo Prestige Blue Raw Data CSV.csv']
# ['Kailh x Varmilo Prestige Red Raw Data CSV.csv']
# ['Keychron Gateron Phantom Brown Raw Data CSV.csv']
# ['Keychron Low Profile Banana Raw Data CSV.csv']
# ['Keychron Low Profile Mint Raw Data CSV.csv']
# ['Keychron Red (Clear_Black) Raw Data CSV.csv']
# ['Keyfirst Bling Blue Raw Data CSV.csv']
# []
# ['Keyfirst Bling Purple Raw Data CSV.csv']
# ['Keyfirst Bling Red Raw Data CSV.csv']
# ['Keyfirst Bling Yellow Raw Data CSV.csv']
# ['KeyGeek Blue and Yellow Sample Raw Data CSV.csv']
# []
# ['KFA Lubed Pink Robin Raw Data CSV.csv']
# ['KFA N2O Laughing Gas Raw Data CSV.csv']
# ['Kinetic Labs Gecko Raw Data CSV.csv']
# ['KNC Keys Black Jacket Raw Data CSV.csv']
# ['Kono Midnight Raw Data CSV.csv']
# ['Kono Sunrise Raw Data CSV.csv']
# ['Kono Sunset Raw Data CSV.csv']
# ['KRGD Blue Raw Data CSV.csv']
# ['KRGD Brown Raw Data CSV.csv']
# ['KTT Blue Jacaranda Raw Data CSV.csv']
# ['KTT Cabbage Tofu (Opaque Top) Raw Data CSV.csv']
# ['KTT Cabbage Tofu (Transparent Top) Raw Data CSV.csv']
# ['KTT Chalk Raw Data CSV.csv']
# ['KTT Cloud Blue (New Mold) Raw Data CSV.csv']
# ['KTT Custard Raw Data CSV.csv']
# ['KTT Darling Raw Data CSV.csv']
# ['KTT Floating Light Raw Data CSV.csv']
# ['KTT Gold Raw Data CSV.csv']
# ['KTT Grey Sample Raw Data CSV.csv']
# ['KTT Iwai Tea Raw Data CSV.csv']
# ['KTT Lightning Raw Data CSV.csv']
# ['KTT Low Profile White Raw Data CSV.csv']
# ['KTT Mango Sago Raw Data CSV.csv']
# ['KTT Marble Raw Data CSV.csv']
# ['KTT Matcha (Blank Nameplate) Raw Data CSV.csv']
# ['KTT Phalaenopsis Raw Data CSV.csv']
# ['KTT Pink and Green Sample Raw Data CSV.csv']
# ['KTT Pink and Lime Green Sample Raw Data CSV.csv']
# ['KTT Pink and Pink Sample Raw Data CSV.csv']
# ['KTT Pink and White Sample Raw Data CSV.csv']
# ['KTT Pink and Yellow Sample Raw Data CSV.csv']
# ['KTT Reccazr KU Brown Raw Data CSV.csv']
# ['KTT Reccazr KU Orange Raw Data CSV.csv']
# ['KTT Soot Raw Data CSV.csv']
# ['KTT Strawberry Raw Data CSV.csv']
# ['LCET Moonlit Night Raw Data CSV.csv']
# []
# ['LCET Wujing Raw Data CSV.csv']
# ['Lelelab Crystal Raw Data CSV.csv']
# ['Lelelab Y2K Raw Data CSV.csv']
# ['Leobog Ashwood Raw Data CSV.csv']
# ['Leobog Ashwood V2 Raw Data CSV.csv']
# ['Leobog Ashwood V3 Raw Data CSV.csv']
# ['Leobog Black Raw Data CSV.csv']
# ['Leobog Ice Soul Raw Data CSV.csv']
# ['Leobog Juggle Raw Data CSV.csv']
# ['Leobog Juggle V2 Raw Data CSV.csv']
# ['Leobog Kayking Raw Data CSV.csv']
# ['Leobog Leek_Chive Raw Data CSV.csv']
# ['Leobog Nimbus Raw Data CSV.csv']
# ['Leobog Nimbus V2 Raw Data CSV.csv']
# ['Leobog Standard Brown Raw Data CSV.csv']
# ['Leobog Wolfberry Raw Data CSV.csv']
# ['Leobog Yiling Raw Data CSV.csv']
# ['Lichicx Green Mustard Raw Data CSV.csv']
# ['LICHICX Lucy 2 Raw Data CSV.csv', 'LICHICX Lucy 3 Raw Data CSV.csv', 'LICHICX Lucy Raw Data CSV.csv']
# ['Lubed Black Geon Switch Raw Data CSV.csv']
# ['Lubed Clear Geon Switch Raw Data CSV.csv']
# ['Lubed Invokeys Blueberry Chiffon Raw Data CSV.csv']
# ['Malvix Studio Irene Raw Data CSV.csv']
# ['Mamba Raw Data CSV.csv']
# ['Matcha Bamboo Shoot Raw Data CSV.csv']
# ['Meirun Orange Sample Raw Data CSV.csv']
# ['Meirun Red Sample Raw Data CSV.csv']
# ['Mekanisk Ultramarine V2 Raw Data CSV.csv']
# ['Mint Chocolate Chip POM Raw Data CSV.csv']
# ["MMD 'Ice' Raw Data CSV.csv"]
# ["MMD 'Strawberry' Raw Data CSV.csv"]
# ['MMD Green and Grey Linear Raw Data CSV.csv']
# ['MMD Green Tactile Raw Data CSV.csv']
# ['MMD Honey Tactile POM Raw Data CSV.csv']
# ['MMD Matcha Ice Cream Raw Data CSV.csv']
# ['MOD-H Linear Raw Data CSV.csv']
# ['MOD-H Tactile Raw Data CSV.csv']
# ['MOD-L Linear Raw Data CSV.csv']
# ['MOD-L Tactile Raw Data CSV.csv']
# []
# ['MOD-M Tactile Raw Data CSV.csv']
# ['MOD-SH Raw Data CSV.csv']
# ['MODE Anthracite Raw Data CSV.csv']
# ['MODE Anthracite Prototype Raw Data CSV.csv']
# ['MODE Obscura Raw Data CSV.csv']
# ['MODE Obscura Prototype Raw Data CSV.csv']
# ['MODE Reflex Raw Data CSV.csv']
# ['MODE Signal Raw Data CSV.csv']
# ['MODE Tomorrow Blue Raw Data CSV.csv']
# ['MODE Tomorrow Blue Prototype Raw Data CSV.csv']
# ['MODE Tomorrow Green Raw Data CSV.csv']
# ['MODE Tomorrow Green Prototype Raw Data CSV.csv']
# ['MODE Tomorrow Orange Raw Data CSV.csv']
# ['MODE Tomorrow Orange Prototype Raw Data CSV.csv']
# ['MODE Tomorrow Purple Raw Data CSV.csv']
# ['MODE Tomorrow Purple Prototype Raw Data CSV.csv']
# ['MODE Tomorrow Yellow Raw Data CSV.csv']
# ['MODE Tomorrow Yellow Prototype Raw Data CSV.csv']
# ['Momoka Frog V3 Raw Data CSV.csv']
# ['Momoka Shark Raw Data CSV.csv']
# ['Moondrop x G-Square Lunalight Raw Data CSV.csv']
# ['Moondrop x G-Square Tessence Raw Data CSV.csv']
# ['Moyu Pansy Raw Data CSV.csv']
# ['Moyu Studio Ice Matcha Raw Data CSV.csv']
# ['Musetsu Raw Data CSV.csv']
# ['Naevy V2 Raw Data CSV.csv']
# ['Neapolitan Ice Cream Raw Data CSV.csv']
# ['Next Time Blue Star Raw Data CSV.csv']
# ['NextTime Engine V3 Raw Data CSV.csv']
# ['NextTime Watermelon Pro Raw Data CSV.csv']
# ['Nightingale Lubed Raw Data CSV.csv']
# ['Nightingale Unlubed Raw Data CSV.csv']
# ['NK Silk Awaken Green Raw Data CSV.csv']
# ['NK Silk Awaken Pink Raw Data CSV.csv']
# ['NK Silk Mictlan Blue Raw Data CSV.csv']
# ['NK Silk Mictlan Orange Raw Data CSV.csv']
# ['NK Silk Mictlan Pink Raw Data CSV.csv']
# ['NK Silk Mictlan Purple Raw Data CSV.csv']
# ['NK Silk Mictlan Yellow Raw Data CSV.csv']
# ['NK TFUE Silk Raw Data CSV.csv']
# ['Novelkeys Box Cream Raw Data CSV.csv']
# ['Novelkeys Cream 2 Raw Data CSV.csv', 'Novelkeys Cream 3 Raw Data CSV.csv', 'Novelkeys Cream Raw Data CSV.csv']
# ['Novelkeys Cream Arc Raw Data CSV.csv']
# ['Novelkeys Cream Arc Inverted Spring Raw Data CSV.csv']
# ['Novelkeys Cream Clickie Raw Data CSV.csv']
# ['Novelkeys Cream Tactile Raw Data CSV.csv']
# ['Novelkeys Cream+ Raw Data CSV.csv']
# ['Novelkeys Cream+ (Copper Insert) Raw Data CSV.csv']
# ['Novelkeys Cream+ (Silicone Insert Proto) Raw Data CSV.csv']
# ['Novelkeys Cream+ (Titanium Insert) Raw Data CSV.csv']
# ['Novelkeys Dream Cream 2 Raw Data CSV.csv', 'Novelkeys Dream Cream 3 Raw Data CSV.csv', 'Novelkeys Dream Cream Raw Data CSV.csv']
# ['Novelkeys Launch Cream Raw Data CSV.csv']
# ['Novelkeys Sherbet Raw Data CSV.csv']
# ['OArmy Green Raw Data CSV.csv']
# ['Obsidian L Raw Data CSV.csv']
# ['Obsidian Pro Raw Data CSV.csv']
# ['Obsidian Pro V2 Raw Data CSV.csv']
# ['Oooolong Raw Data CSV.csv']
# ['Opblack Raw Data CSV.csv']
# ['Outemu Bai Lan Raw Data CSV.csv']
# ['Outemu Cream Top Milk Green Raw Data CSV.csv']
# ['Outemu Cream Top Milk Peach Raw Data CSV.csv']
# ['Outemu Cream Top Milk Tea Raw Data CSV.csv']
# ['Outemu Jerry Raw Data CSV.csv']
# ['Outemu Milk Green Raw Data CSV.csv']
# ['Outemu Milk Peach Raw Data CSV.csv']
# ['Outemu Milk Tea Raw Data CSV.csv']
# ['Outemu Ocean Silent Dustproof Linear Raw Data CSV.csv']
# ['Outemu Ocean Silent Linear Raw Data CSV.csv']
# ['Outemu Tom Raw Data CSV.csv']
# ['Owlabs Neon Raw Data CSV.csv']
# ['Oxford Micro Optical Orange Raw Data CSV.csv']
# ['Penguin Lubed Raw Data CSV.csv']
# ['Philikeys Pink Raw Data CSV.csv']
# ['Philikeys White Raw Data CSV.csv']
# ['Pink 43Studio Prototype Raw Data CSV.csv']
# ['Polycarbonate over Nylon Matcha Latte V2 Prototype Raw Data CSV.csv']
# ['Popcorn Raw Data CSV.csv']
# ['Popu Raw Data CSV.csv']
# ['Prevail Key Co Nebula Raw Data CSV.csv']
# ['ProWorld Clicky Raw Data CSV.csv']
# ['PunkShoo Melody Factory Error Raw Data CSV.csv']
# ['Qeeke Mica Raw Data CSV.csv']
# ['Quartz V2 Raw Data CSV.csv']
# ['Raed V2 Raw Data CSV.csv']
# ['RAMA WORKS Duck Raw Data CSV.csv']
# ['RAMA WORKS Duck Sample 1 Raw Data CSV.csv']
# ['RAMA WORKS Duck Sample 2 Raw Data CSV.csv']
# ['Red Jacket Raw Data CSV.csv']
# ['Redragon Panda Raw Data CSV.csv']
# ['Redragon Sapphie Raw Data CSV.csv']
# ['Redragon Thin Lemon Raw Data CSV.csv']
# ['RK Celadon Raw Data CSV.csv']
# ['RK Golden Purple Raw Data CSV.csv']
# ['RK Latte Raw Data CSV.csv']
# ['RK Sakura Raw Data CSV.csv']
# ['RK Sea Blue Raw Data CSV.csv']
# ['RK White Raw Data CSV.csv']
# ['Rococo Tactile Raw Data CSV.csv']
# ['Rubrehose Brown Raw Data CSV.csv']
# ['Rubrehose Grey Raw Data CSV.csv']
# ['S1 Peaches Raw Data CSV.csv']
# ['Safety Raw Data CSV.csv']
# ['Sakurio Raw Data CSV.csv']
# ['Saybour Optical Blue Raw Data CSV.csv']
# ['Silent Alpaca Raw Data CSV.csv']
# ['Silent Blue Macaw Raw Data CSV.csv']
# ['Silent Coral Raw Data CSV.csv']
# ['Skyloong Brown Iceberg Raw Data CSV.csv']
# ['Skyloong Pink Iceberg Raw Data CSV.csv']
# ['Skyloong Red Iceberg Raw Data CSV.csv']
# ['Skyloong Silent Brown Iceberg Raw Data CSV.csv']
# ['Skyloong Silent Pink Iceberg Raw Data CSV.csv']
# ['Skyloong Silent Red Iceberg Raw Data CSV.csv']
# ['Skyloong Silent Silver Iceberg Raw Data CSV.csv']
# ['Skyloong Silent White Iceberg Raw Data CSV.csv']
# ['Skyloong Silent Yellow Iceberg Raw Data CSV.csv']
# ['Skyloong Silver Iceberg Raw Data CSV.csv']
# ['Skyloong White Iceberg Raw Data CSV.csv']
# ['Skyloong Yellow Iceberg Raw Data CSV.csv']
# ['SOTC Raw Data CSV.csv']
# ['SP Star Meteor Grey (Grey Housing) Raw Data CSV.csv']
# ['SP Star Meteor Orange (Grey Housing) Raw Data CSV.csv']
# ['SP Star Meteor Purple (Grey Housing) Raw Data CSV.csv']
# ['SP Star Meteor White (Grey Housing) Raw Data CSV.csv']
# ['SP Star Sacramento Raw Data CSV.csv']
# ['Splash Brothers Raw Data CSV.csv']
# ['Strawberry Jelly V4 Raw Data CSV.csv']
# ['Strawberry Milk Ice Linear Raw Data CSV.csv']
# ['Strawberry Milk Ice Tactile Raw Data CSV.csv']
# ['Sunny Side Up Linear Raw Data CSV.csv']
# ['Swagkeys Bubble Raw Data CSV.csv']
# ['Swirl Red Raw Data CSV.csv']
# ['Tamago Sushi 1 Raw Data CSV.csv', 'Tamago Sushi 2 Raw Data CSV.csv', 'Tamago Sushi 3 Raw Data CSV.csv']
# ['Tealio V2 Raw Data CSV.csv']
# ['TeamWolf Black Raw Data CSV.csv']
# ['TeamWolf Blue Raw Data CSV.csv']
# ['TeamWolf Optical Green 4.0 Raw Data CSV.csv']
# ['TeamWolf Optical Tan 2.0 Raw Data CSV.csv']
# ['TeamWolf Optical Tan 4.0 Raw Data CSV.csv']
# ['TeamWolf Red Raw Data CSV.csv']
# ['TeamWolf x Manic Red Raw Data CSV.csv']
# ['Techno Violet V1 Raw Data CSV.csv']
# ['Tecsee Coral Raw Data CSV.csv']
# ['Tecsee Ice Milk Tactile Raw Data CSV.csv']
# ['Tecsee Lake Blue Raw Data CSV.csv']
# ['Tecsee Middle Switch Linear Raw Data CSV.csv']
# ['Tecsee Middle Switch Tactile Raw Data CSV.csv']
# ['Tecsee Sky Blue Cloud Linear Raw Data CSV.csv']
# ['Tecsee Sky Blue Cloud Tactile Raw Data CSV.csv']
# ['Tecsee Strawberry Ice Raw Data CSV.csv']
# ['Teton Cream Raw Data CSV.csv']
# ['TKC Blackberry Raw Data CSV.csv']
# ['TofuTypes x KNC Keys Tofu Raw Data CSV.csv']
# ['Toy Brick Raw Data CSV.csv']
# ['Transmit (52g) Raw Data CSV.csv']
# ['Transmit (62g) Raw Data CSV.csv']
# ['Transmit Garage Kit Raw Data CSV.csv']
# ['Transmit Green (42g) Raw Data CSV.csv']
# ['Transmit Iced Tea Raw Data CSV.csv']
# ['Transmit Small Iceberg Raw Data CSV.csv']
# ['Transmit Toy Raw Data CSV.csv']
# ['Trash Linear Raw Data CSV.csv']
# ['Tropical Water V2 Raw Data CSV.csv']
# ['TTC Ace V1.5 Raw Data CSV.csv']
# ['TTC Ace V2 Raw Data CSV.csv']
# ['TTC Bluish White (Full Silent) Raw Data CSV.csv']
# ['TTC Chaotic Panda Raw Data CSV.csv']
# ['TTC Cloud V2 Raw Data CSV.csv']
# ['TTC Cyber Panda Raw Data CSV.csv']
# ['TTC Flame Purple Raw Data CSV.csv']
# ['TTC Flame Red Half Height LED Raw Data CSV.csv']
# ['TTC Frozen V2 Raw Data CSV.csv']
# ['TTC Gold Brown Pro Raw Data CSV.csv']
# ['TTC Gold Red Pro Raw Data CSV.csv']
# ['TTC Gold Silver Pro Raw Data CSV.csv']
# ['TTC K Series Black Raw Data CSV.csv']
# ['TTC K Series Blue Raw Data CSV.csv']
# ['TTC K Series Brown Raw Data CSV.csv']
# ['TTC K Series Red Raw Data CSV.csv']
# ['TTC Love Raw Data CSV.csv']
# ['TTC Matrix 01 Linear Raw Data CSV.csv']
# ['TTC Matrix 01 Tactile Raw Data CSV.csv']
# ['TTC MT Blue Raw Data CSV.csv']
# ['TTC MT Red Raw Data CSV.csv']
# ['TTC NCR V2 Raw Data CSV.csv']
# ['TTC Neptune Raw Data CSV.csv']
# ['TTC Old School Raw Data CSV.csv']
# ['TTC Orange V2 Brown Raw Data CSV.csv']
# ['TTC Orange V2 Red Raw Data CSV.csv']
# ['TTC Razer Dustproof Green Raw Data CSV.csv']
# ['TTC Razer Dustproof Orange Raw Data CSV.csv']
# ['TTC Razer Dustproof Yellow Raw Data CSV.csv']
# ['TTC Silent Red V2 Raw Data CSV.csv']
# ['TTC Speed Silver Raw Data CSV.csv']
# ['TTC Tiger Raw Data CSV.csv']
# ['TTC Venus Raw Data CSV.csv']
# ['TTC Wild (42g) Raw Data CSV.csv']
# ['TTC Wild (55g) Raw Data CSV.csv']
# ['TTC x Varmilo Speed Gold Raw Data CSV.csv']
# ['TTC Yellow Top Brown Raw Data CSV.csv']
# ['TTC Yellow Top Brown (Lightbar) Raw Data CSV.csv']
# ['U4TX Plum Raw Data CSV.csv']
# ['Ube Crinkle Cookie Raw Data CSV.csv']
# ['Unlabeled Matcha Latte V2 Prototype Raw Data CSV.csv']
# ['Unlubed Invokeys Blueberry Chiffon Raw Data CSV.csv']
# ['Varmilo EC V2 Iris Raw Data CSV.csv']
# ['Varmilo EC V2 Jasmine Raw Data CSV.csv']
# ['Varmilo EC V2 Moxa Raw Data CSV.csv']
# ['Varmilo EC V2 Orange Raw Data CSV.csv']
# ['Varmilo EC V2 Violet Raw Data CSV.csv']
# ['Whale Works x Illusion Illusion Raw Data CSV.csv']
# ['Wooting Lekker Raw Data CSV.csv']
# ['WS Aurora Pink Raw Data CSV.csv']
# ['WS Onion Raw Data CSV.csv']
# ['Wuque Studio Dustproof Grey Raw Data CSV.csv']
# ['Wuque Studio Dustproof White Raw Data CSV.csv']
# ['Wuque Studio Morandi Raw Data CSV.csv']
# ['YOK EMT V1 Raw Data CSV.csv']
# ['Zaku (Nameplate) Raw Data CSV.csv']
# ['Zealio V1 Redux 62g Raw Data CSV.csv']
# ['Zealio V2 AC 62g Raw Data CSV.csv']
# ['Zealio V2 AC 78g Raw Data CSV.csv']
# ['Zepsody Bluebonnet Raw Data CSV.csv']
# ['Zorro Black (White Bottom) Raw Data CSV.csv']
# ['Zorro Blue (White Bottom) Raw Data CSV.csv']
# ['Zorro Brown (White Bottom) Raw Data CSV.csv']
# ['Zorro Red (White Bottom) Raw Data CSV.csv']

# %%
list(os.walk('../'))[0]
# Out:
# ('../',
#  ['.git',
#   '.idea',
#   '0_data_process',
#   'A Switch With No Good Name',
#   'Aflion Black and Orange',
#   'Aflion Blue Sky',
#   'Aflion Blush',
#   'Aflion Holy Panda',
#   'Aflion Iceberg Rainbow Blue',
#   'Aflion Tropical Waters',
#   'Agile Moon',
#   'Ajazz AS Coral Pink',
#   'Ajazz AS Foggy Mountain Green',
#   'Ajazz AS Royal Yellow',
#   'Ajazz AS Sky Blue',
#   'Ajazz Brown (Clear Top, Black Bottom)',
#   'Ajazz Doyu Orange',
#   'Ajazz Doyu White',
#   'Ajazz Purple',
#   'Ajazz x Huano Banana',
#   'Ajazz x Huano Peach',
#   'Akko Air',
#   'Akko Blue V2',
#   'Akko Crystal',
#   'Akko Crystal Blue',
#   'Akko Crystal Silver',
#   'Akko Crystal Wine Red',
#   'Akko CS Jelly Black',
#   'Akko CS Jelly Blue',
#   'Akko CS Jelly Pink',
#   'Akko CS Jelly Purple',
#   'Akko CS Jelly White',
#   'Akko CS Lavender Purple',
#   'Akko CS Radiant Red',
#   'Akko CS Sponge',
#   'Akko CS Starfish',
#   'Akko CS Vintage White',
#   'Akko CS Wine White',
#   'Akko Orange V1',
#   'Akko POM Brown',
#   'Akko POM Pink',
#   'Akko POM Silver',
#   'Akko Snow Blue Grey',
#   'Akko V3 Cream Blue',
#   'Akko V3 Cream Yellow',
#   'Akko Wine Red',
#   'All Clack',
#   'AngryMiao Cyberswitch',
#   'Aristotle White',
#   'Asus Rog NX Blue',
#   'Asus Rog NX Brown',
#   'Asus Rog NX Red',
#   'BBN (Tactile)',
#   'BBN Linear',
#   'Betty',
#   'Bingsu POM',
#   'Black Geon Switch',
#   'Blaeck',
#   'Bluejay',
#   'Bobagum (62g)',
#   'Bolsa Namazu',
#   'Brazilian Iron',
#   'BSUN Avocado Panda V2',
#   'BSUN Crystal Light Blue',
#   'BSUN Crystal White',
#   'BSUN Dragon Fruit Panda V2',
#   'BSUN Dustproof Blue',
#   'BSUN Ginseng Fruit',
#   'BSUN Light Switch',
#   'BSUN Lychee Black',
#   'BSUN Lychee Red',
#   'BSUN Peach Pride',
#   'BSUN Pikachu',
#   'BSUN Polar Panda V2',
#   'BSUN POM Panda Black',
#   'BSUN POM Panda Red',
#   'BSUN Racoon Panda V2',
#   'BSUN Smoky Pink Tactile',
#   'BSUN Yellow (Clear_White)',
#   'C3 Equalz Tangerine V2 (62g)',
#   'C3 Kiwi',
#   'Ca Phe Sua Da',
#   'Cardinal',
#   'CHAOSERA Klein',
#   'Cherry Blossom',
#   'Cherry Hirose Clear',
#   'Cherry Hirose Orange',
#   "Cherry MX 'New Nixie' (Black Clear-Top)",
#   'Cherry MX Black',
#   'Cherry MX Blue',
#   'Cherry MX Brown',
#   'Cherry MX Clear',
#   'Cherry MX Green',
#   'Cherry MX Hyperglide Black (3 Pin)',
#   'Cherry MX Hyperglide Black (5 Pin)',
#   'Cherry MX Hyperglide Brown',
#   'Cherry MX Jailhouse Blue',
#   'Cherry MX Linear Grey',
#   'Cherry MX Lock',
#   'Cherry MX Red',
#   'Cherry MX Tactile Grey',
#   'Cherry MX White',
#   'Cherry MX_M8 Black Adapter',
#   'Cherry MX_M8 White Adapter',
#   'Cherry Nixdorf Black',
#   'Cherry Nixdorf White',
#   'Chocolate Toffee Linear',
#   'Chosfox x JWICK Voyager',
#   'CIY Evolution Red',
#   'CK x Haimu Pastel Lemon',
#   'CK x Haimu Pastel Mint',
#   'CK x Haimu Pastel Peach',
#   'Clickiez 40g Clicky',
#   'Clickiez 40g Linear',
#   'Clickiez 40g Tactile',
#   'Clickiez 75g Clicky',
#   'Clickiez 75g Linear',
#   'Clickiez 75g Tactile',
#   'Commute',
#   "Cookies n' Cream",
#   'Corsa',
#   'Cotton Candy',
#   'Crow',
#   'DareU Candy Pink V1',
#   'DareU Sky Blue V3',
#   'DareU Sky V2',
#   'DareU Violet Gold Pro',
#   'DareU Violet_Purple Gold V2',
#   'Designer Studio Graphite Gold',
#   'Designer Studio Retro Light Blue',
#   'Designer Studio Retro Light Green',
#   'Designer Studio Retro Light Red',
#   'Designer Studio Starry',
#   'Designer Studio Taoyao',
#   'dk Oni',
#   'Doom Tactile',
#   'Durock Black Lotus (63.5g)',
#   'Durock Black Lotus (80g)',
#   'Durock Blush',
#   'Durock POM Linear',
#   'Durock Shrimp',
#   'Emogogo Grey',
#   'Emogogo White',
#   'EMT V1',
#   'EMT V2',
#   'Epomaker Bluebird',
#   'Epomaker Budgreigar',
#   'Epomaker Comte',
#   'Epomaker Flamingo',
#   'Epsilon V2',
#   'Feker Emerald Yellow',
#   'Feker Matcha',
#   'Feker White Marble',
#   'Firstblood Blue',
#   'Firstblood Pink',
#   'FLCMMK Bauhinia',
#   'FLCMMK Box Rosa Pink',
#   'FLCMMK Ice Mint',
#   'Forgiven',
#   'G-Square Black Warrior V2',
#   'G-Square Dreamland Linear',
#   'G-Square Dreamland Tactile',
#   'G-Square White Warrior',
#   'Ganss Lunar Blue',
#   'Ganss Lunar Grey',
#   'Gateron Azure Dragon V2',
#   'Gateron Baby Kangaroo',
#   'Gateron Baby Racoon',
#   'Gateron Box Ink Pink',
#   'Gateron Camping',
#   'Gateron Cap Crystal Blue',
#   'Gateron Cap Crystal Brown',
#   'Gateron Cap Crystal Red',
#   'Gateron Cap Crystal Silent Red',
#   'Gateron Cap Crystal Silver',
#   'Gateron Cap Crystal Yellow',
#   'Gateron CAP Yellow V2',
#   'Gateron CJ Light Blue',
#   'Gateron Cream Soda',
#   'Gateron FC',
#   'Gateron Holy Panda X',
#   'Gateron Holy Panda X Prototype',
#   'Gateron Kangaroo Ink',
#   'Gateron KS9 Pro 2.0 Black',
#   'Gateron KS9 Pro 2.0 Blue',
#   'Gateron KS9 Pro 2.0 Brown',
#   'Gateron KS9 Pro 2.0 Red',
#   'Gateron KS9 Pro 2.0 Silver',
#   'Gateron KS9 Pro 2.0 White',
#   'Gateron KS9 Pro 2.0 Yellow',
#   'Gateron Limbo',
#   'Gateron Lion',
#   'Gateron Mini',
#   'Gateron Mink',
#   'Gateron Mizu Mink',
#   'Gateron North Pole',
#   'Gateron Oil King',
#   'Gateron Phantom Blue',
#   'Gateron Phantom Red',
#   'Gateron Root Beer Float',
#   'Gateron Root Beer Float (New Pin)',
#   'Gateron Silent Ink V2',
#   'Gateron UHMknown',
#   'Gateron Unicorn',
#   'Gateron Vermillion Bird',
#   'Gateron X',
#   'Gateron x Swagkeys Pure Berry',
#   'Gateron X V2',
#   'Gatistotle',
#   'Gazzew Phoenix Final 75g',
#   'Gazzew Phoenix V1 75g',
#   'Gazzew Phoenix V2 75g',
#   'Glorious Fox',
#   'GoPolar Yang',
#   'GoPolar Yin',
#   'Grain Gold Blue Linear Sample',
#   'Grain Gold Neon V1',
#   'Grain Gold Neon V2',
#   'Grain Gold Tom Gold Pink',
#   'Green Jacket Linear',
#   'Green Jacket Tactile',
#   'Greetech Black (Clear_White, 3 Pin)',
#   'Greetech Blue (Black Housing)',
#   'Greetech Blue (Clear_White, 5 Pin)',
#   'Gypsophilia 1',
#   'Gypsophilia 2',
#   'Gypsophilia 3',
#   'Gypsophilia 4',
#   'Gypsophilia 5',
#   'Gypsophilia 6',
#   'Hades',
#   'Haimu Heartbeat',
#   'Haimu Whisper',
#   'Haimu x Geon White',
#   'Haimu x Geon Yellow',
#   'HAPE Orange',
#   'HCP Hirose Clear',
#   'HiGround x TTC Titan Heart',
#   'HK Gaming MS-1 Pro Lake Blue',
#   'HK Gaming MS-1 Pro Marlin Blue',
#   'HK Gaming MS-1 Pro Sky Blue',
#   'Honeycomb',
#   'Hoshizora',
#   'Huano Dustproof Purple & Hot Pink (Grey Bottom)',
#   'Huano Earth Yellow',
#   'Huano Hot Pink',
#   'Huano Pandora',
#   'Huano Pineapple',
#   'Huano Pink',
#   'Huano Purple',
#   'Huano Red-Orange',
#   'Huano Silver',
#   'Huano Spirit Wind',
#   'Huano Teal',
#   'Huano Turquoise',
#   'Husky',
#   'HyperX Aqua',
#   'HyperX Blue',
#   'HyperX Red',
#   'In Former Days',
#   'Invokeys Black Sesame',
#   'Invokeys Blueberry Chiffon HDPE Prototype R1',
#   'Invokeys Blueberry Chiffon Prototype R1',
#   'Invokeys Blueberry Chiffon Prototype R2',
#   'Invokeys Matcha Latte',
#   'Invyr Holy Panda',
#   'Jerrzi Black',
#   'Jerrzi Blue',
#   'Jerrzi Brown',
#   'Jerrzi Coral',
#   'Jerrzi Dustproof Clear',
#   'Jerrzi Dustproof Pink',
#   'Jerrzi Dustproof White',
#   'Jerrzi Dustproof Yellow',
#   'Jerrzi Kyria Brown',
#   'Jerrzi Kyria Grey',
#   'Jerrzi Kyria Pink',
#   'Jerrzi Kyria Red',
#   'Jerrzi Kyria White',
#   'Jerrzi Kyria Yellow',
#   'Jerrzi Orange',
#   'Jerrzi Red',
#   'Jerrzi Seashell',
#   'Jerrzi Violet',
#   'Jerrzi Yellow',
#   'Jixian Blue',
#   'JKLP Holy Panda',
#   'JWICK Ginger Milk',
#   'JWICK Ice White',
#   'JWICK Red',
#   'JWICK Semi Silent',
#   'JWICK T1',
#   'JWICK Taro',
#   'JWICK Ultimate Black',
#   'JWICK Yellow',
#   'JWK Black CV1',
#   'JWK Black CV2',
#   'JWK Blue Lotus',
#   'JWK Bluey',
#   'JWK CW',
#   'JWK DIE FOR ME',
#   'JWK F1',
#   'JWK Pink-Jade',
#   'Kailh Arctic Fox',
#   'Kailh Arctic Fox V2',
#   'Kailh Box Ancient Grey',
#   'Kailh Box Jade',
#   'Kailh Box Navy',
#   'Kailh Box Speed Ultimate',
#   'Kailh Box Summer (Zhixia)',
#   'Kailh Box V2 Brown',
#   'Kailh Box V2 Red',
#   'Kailh Box V2 White',
#   'Kailh Chinoiserie Delo',
#   'Kailh Christmas Tree',
#   'Kailh Crystal Burgundy',
#   'Kailh Deep Sea',
#   'Kailh MX Star',
#   'Kailh Pink Unicorn',
#   'Kailh Pro Burgundy (PCB Mount)',
#   'Kailh Pro Burgundy (Plate Mount)',
#   'Kailh Pro Heavy Berry (PCB Mount)',
#   'Kailh Pro Heavy Berry (Plate Mount)',
#   'Kailh Pro Heavy Plum (PCB Mount)',
#   'Kailh Pro Heavy Plum (Plate Mount)',
#   'Kailh Pro Heavy Sage (PCB Mount)',
#   'Kailh Pro Heavy Sage (Plate Mount)',
#   'Kailh Pro Light Green (PCB Mount)',
#   'Kailh Pro Light Green (Plate Mount)',
#   'Kailh Pro Midnight Grey',
#   'Kailh Pro Midnight Light Yellow',
#   'Kailh Pro Purple (PCB Mount)',
#   'Kailh Pro Purple (Plate Mount)',
#   'Kailh Santa Hat',
#   'Kailh Speed Bronze (Plate Mount)',
#   'Kailh Speed Copper (PCB Mount)',
#   'Kailh Speed Copper (Plate Mount)',
#   'Kailh Speed Gold (PCB Mount)',
#   'Kailh Speed Gold (Plate Mount)',
#   'Kailh Speed Pink',
#   'Kailh Speed Silver (PCB Mount)',
#   'Kailh Speed Silver (Plate Mount)',
#   'Kailh Sunset Tactile Choc',
#   'Kailh Super Speed Red',
#   'Kailh Super Speed Silver',
#   'Kailh White Owl',
#   'Kailh x Varmilo Prestige Blue',
#   'Kailh x Varmilo Prestige Red',
#   'Keychron Gateron Phantom Brown',
#   'Keychron Low Profile Banana',
#   'Keychron Low Profile Mint',
#   'Keychron Red (Clear_Black)',
#   'Keyfirst Bling Blue',
#   'Keyfirst Bling Green',
#   'Keyfirst Bling Purple',
#   'Keyfirst Bling Red',
#   'Keyfirst Bling Yellow',
#   'KeyGeek Blue and Yellow Sample',
#   'KeyGeek Raw',
#   'KFA Lubed Pink Robin',
#   'KFA N2O Laughing Gas',
#   'Kinetic Labs Gecko',
#   'KNC Keys Black Jacket',
#   'Kono Midnight',
#   'Kono Sunrise',
#   'Kono Sunset',
#   'KRGD Blue',
#   'KRGD Brown',
#   'KTT Blue Jacaranda',
#   'KTT Cabbage Tofu (Opaque Top)',
#   'KTT Cabbage Tofu (Transparent Top)',
#   'KTT Chalk',
#   'KTT Cloud Blue (New Mold)',
#   'KTT Custard',
#   'KTT Darling',
#   'KTT Floating Light',
#   'KTT Gold',
#   'KTT Grey Sample',
#   'KTT Iwai Tea',
#   'KTT Lightning',
#   'KTT Low Profile White',
#   'KTT Mango Sago',
#   'KTT Marble',
#   'KTT Matcha (Blank Nameplate)',
#   'KTT Phalaenopsis',
#   'KTT Pink and Green Sample',
#   'KTT Pink and Lime Green Sample',
#   'KTT Pink and Pink Sample',
#   'KTT Pink and White Sample',
#   'KTT Pink and Yellow Sample',
#   'KTT Reccazr KU Brown',
#   'KTT Reccazr KU Orange',
#   'KTT Soot',
#   'KTT Strawberry',
#   'LCET Moonlit Night',
#   'LCET Sea Night',
#   'LCET Wujing',
#   'Lelelab Crystal',
#   'Lelelab Y2K',
#   'Leobog Ashwood',
#   'Leobog Ashwood V2',
#   'Leobog Ashwood V3',
#   'Leobog Black',
#   'Leobog Ice Soul',
#   'Leobog Juggle',
#   'Leobog Juggle V2',
#   'Leobog Kayking',
#   'Leobog Leek_Chive',
#   'Leobog Nimbus',
#   'Leobog Nimbus V2',
#   'Leobog Standard Brown',
#   'Leobog Wolfberry',
#   'Leobog Yiling',
#   'Lichicx Green Mustard',
#   'LICHICX Lucy',
#   'Lubed Black Geon Switch',
#   'Lubed Clear Geon Switch',
#   'Lubed Invokeys Blueberry Chiffon',
#   'Malvix Studio Irene',
#   'Mamba',
#   'Matcha Bamboo Shoot',
#   'Meirun Orange Sample',
#   'Meirun Red Sample',
#   'Mekanisk Ultramarine V2',
#   'Mint Chocolate Chip POM',
#   "MMD 'Ice'",
#   "MMD 'Strawberry'",
#   'MMD Green and Grey Linear',
#   'MMD Green Tactile',
#   'MMD Honey Tactile POM',
#   'MMD Matcha Ice Cream',
#   'MOD-H Linear',
#   'MOD-H Tactile',
#   'MOD-L Linear',
#   'MOD-L Tactile',
#   'MOD-M Linear',
#   'MOD-M Tactile',
#   'MOD-SH',
#   'MODE Anthracite',
#   'MODE Anthracite Prototype',
#   'MODE Obscura',
#   'MODE Obscura Prototype',
#   'MODE Reflex',
#   'MODE Signal',
#   'MODE Tomorrow Blue',
#   'MODE Tomorrow Blue Prototype',
#   'MODE Tomorrow Green',
#   'MODE Tomorrow Green Prototype',
#   'MODE Tomorrow Orange',
#   'MODE Tomorrow Orange Prototype',
#   'MODE Tomorrow Purple',
#   'MODE Tomorrow Purple Prototype',
#   'MODE Tomorrow Yellow',
#   'MODE Tomorrow Yellow Prototype',
#   'Momoka Frog V3',
#   'Momoka Shark',
#   'Moondrop x G-Square Lunalight',
#   'Moondrop x G-Square Tessence',
#   'Moyu Pansy',
#   'Moyu Studio Ice Matcha',
#   'Musetsu',
#   'Naevy V2',
#   'Neapolitan Ice Cream',
#   'Next Time Blue Star',
#   'NextTime Engine V3',
#   'NextTime Watermelon Pro',
#   'Nightingale Lubed',
#   'Nightingale Unlubed',
#   'NK Silk Awaken Green',
#   'NK Silk Awaken Pink',
#   'NK Silk Mictlan Blue',
#   'NK Silk Mictlan Orange',
#   'NK Silk Mictlan Pink',
#   'NK Silk Mictlan Purple',
#   'NK Silk Mictlan Yellow',
#   'NK TFUE Silk',
#   'Novelkeys Box Cream',
#   'Novelkeys Cream',
#   'Novelkeys Cream Arc',
#   'Novelkeys Cream Arc Inverted Spring',
#   'Novelkeys Cream Clickie',
#   'Novelkeys Cream Tactile',
#   'Novelkeys Cream+',
#   'Novelkeys Cream+ (Copper Insert)',
#   'Novelkeys Cream+ (Silicone Insert Proto)',
#   'Novelkeys Cream+ (Titanium Insert)',
#   'Novelkeys Dream Cream',
#   'Novelkeys Launch Cream',
#   'Novelkeys Sherbet',
#   'OArmy Green',
#   'Obsidian L',
#   'Obsidian Pro',
#   'Obsidian Pro V2',
#   'Oooolong',
#   'Opblack',
#   'Outemu Bai Lan',
#   'Outemu Cream Top Milk Green',
#   'Outemu Cream Top Milk Peach',
#   'Outemu Cream Top Milk Tea',
#   'Outemu Jerry',
#   'Outemu Milk Green',
#   'Outemu Milk Peach',
#   'Outemu Milk Tea',
#   'Outemu Ocean Silent Dustproof Linear',
#   'Outemu Ocean Silent Linear',
#   'Outemu Tom',
#   'Owlabs Neon',
#   'Oxford Micro Orange',
#   'Penguin (Lubed)',
#   'Philikeys Pink',
#   'Philikeys White',
#   'Pink 43Studio Prototype',
#   'Polycarbonate over Nylon Invokeys Matcha Latte V2 Prototype',
#   'Popcorn',
#   'Popu',
#   'Prevail Key Co Nebula',
#   'ProWorld Clicky',
#   'PunkShoo Melody Factory Error',
#   'Qeeke Mica',
#   'Quartz V2',
#   'Raed V2',
#   'RAMA WORKS Duck',
#   'RAMA WORKS Duck Sample 1',
#   'RAMA WORKS Duck Sample 2',
#   'Red Jacket',
#   'Redragon Panda',
#   'Redragon Sapphire',
#   'Redragon Thin Lemon',
#   'RK Celadon',
#   'RK Golden Purple',
#   'RK Latte',
#   'RK Sakura',
#   'RK Sea Blue',
#   'RK White',
#   'Rococo Tactile',
#   'Rubrehose Brown',
#   'Rubrehose Grey',
#   'S1 Peaches',
#   'Safety',
#   'Sakurio',
#   'Saybour Optical Blue',
#   'Silent Alpaca',
#   'Silent Blue Macaw',
#   'Silent Coral',
#   'Skyloong Brown Iceberg',
#   'Skyloong Pink Iceberg',
#   'Skyloong Red Iceberg',
#   'Skyloong Silent Brown Iceberg',
#   'Skyloong Silent Pink Iceberg',
#   'Skyloong Silent Red Iceberg',
#   'Skyloong Silent Silver Iceberg',
#   'Skyloong Silent White Iceberg',
#   'Skyloong Silent Yellow Iceberg',
#   'Skyloong Silver Iceberg',
#   'Skyloong White Iceberg',
#   'Skyloong Yellow Iceberg',
#   'SOTC',
#   'SP Star Meteor Grey (Grey Housing)',
#   'SP Star Meteor Orange (Grey Housing)',
#   'SP Star Meteor Purple (Grey Housing)',
#   'SP Star Meteor White (Grey Housing)',
#   'SP Star Sacramento',
#   'Splash Brothers',
#   'Strawberry Jelly V4',
#   'Strawberry Milk Ice Linear',
#   'Strawberry Milk Ice Tactile',
#   'Sunny Side Up Linear',
#   'Swagkeys Bubble',
#   'Swirl Red',
#   'Tamago Sushi',
#   'Tealio V2',
#   'TeamWolf Black',
#   'TeamWolf Blue',
#   'TeamWolf Optical Green 4.0',
#   'TeamWolf Optical Tan 2.0',
#   'TeamWolf Optical Tan 4.0',
#   'TeamWolf Red',
#   'TeamWolf x Manic Red',
#   'Techno Violet V1',
#   'Tecsee Coral',
#   'Tecsee Ice Milk Tactile',
#   'Tecsee Lake Blue',
#   'Tecsee Middle Switch Linear',
#   'Tecsee Middle Switch Tactile',
#   'Tecsee Sky Blue Cloud Linear',
#   'Tecsee Sky Blue Cloud Tactile',
#   'Tecsee Strawberry Ice',
#   'Teton Cream',
#   'TKC Blackberry',
#   'TofuTypes x KNC Keys Tofu',
#   'Toy Brick',
#   'Transmit (52g)',
#   'Transmit (62g)',
#   'Transmit Garage Kit',
#   'Transmit Green (42g)',
#   'Transmit Iced Tea',
#   'Transmit Small Iceberg',
#   'Transmit Toy',
#   'Trash Linear',
#   'Tropical Water V2',
#   'TTC Ace V1.5',
#   'TTC Ace V2',
#   'TTC Bluish White (Full Silent)',
#   'TTC Chaotic Panda',
#   'TTC Cloud V2',
#   'TTC Cyber Panda',
#   'TTC Flame Purple',
#   'TTC Flame Red Half Height LED',
#   'TTC Frozen V2',
#   'TTC Gold Brown Pro',
#   'TTC Gold Red Pro',
#   'TTC Gold Silver Pro',
#   'TTC K Series Black',
#   'TTC K Series Blue',
#   'TTC K Series Brown',
#   'TTC K Series Red',
#   'TTC Love',
#   'TTC Matrix 01 Linear',
#   'TTC Matrix 01 Tactile',
#   'TTC MT Blue',
#   'TTC MT Red',
#   'TTC NCR V2',
#   'TTC Neptune',
#   'TTC Old School',
#   'TTC Orange V2 Brown',
#   'TTC Orange V2 Red',
#   'TTC Razer Dustproof Green',
#   'TTC Razer Dustproof Orange',
#   'TTC Razer Dustproof Yellow',
#   'TTC Silent Red V2',
#   'TTC Speed Silver',
#   'TTC Tiger',
#   'TTC Venus',
#   'TTC Wild (42g)',
#   'TTC Wild (55g)',
#   'TTC x Varmilo Speed Gold',
#   'TTC Yellow Top Brown',
#   'TTC Yellow Top Brown (Lightbar)',
#   'U4TX Plum',
#   'Ube Crinkle Cookie',
#   'Unlabeled Invokeys Matcha Latte V2 Prototype',
#   'Unlubed Invokeys Blueberry Chiffon',
#   'Varmilo EC V2 Iris',
#   'Varmilo EC V2 Jasmine',
#   'Varmilo EC V2 Moxa',
#   'Varmilo EC V2 Orange',
#   'Varmilo EC V2 Violet',
#   'Whale Works x Illusion Illusion',
#   'Wooting Lekker',
#   'WS Aurora Pink',
#   'WS Onion',
#   'Wuque Studio Dustproof Grey',
#   'Wuque Studio Dustproof White',
#   'Wuque Studio Morandi',
#   'YOK EMT V1',
#   'Zaku (Nameplate)',
#   'Zealio V1 Redux 62g',
#   'Zealio V2 AC (62g)',
#   'Zealio V2 AC (78g)',
#   'Zepsody Bluebonnet',
#   'Zorro Black (White Bottom)',
#   'Zorro Blue (White Bottom)',
#   'Zorro Brown (White Bottom)',
#   'Zorro Red (White Bottom)'],
#  ['1-Force Curve Measurements.xlsx', 'README.md'])

# %%
for x in os.walk('../'):
    print(x[0])
# Out:
# ../
# ../.git
# ../.git\hooks
# ../.git\info
# ../.git\logs
# ../.git\logs\refs
# ../.git\logs\refs\heads
# ../.git\logs\refs\remotes
# ../.git\logs\refs\remotes\origin
# ../.git\objects
# ../.git\objects\info
# ../.git\objects\pack
# ../.git\refs
# ../.git\refs\heads
# ../.git\refs\remotes
# ../.git\refs\remotes\origin
# ../.git\refs\tags
# ../.idea
# ../.idea\inspectionProfiles
# ../0_data_process
# ../A Switch With No Good Name
# ../Aflion Black and Orange
# ../Aflion Blue Sky
# ../Aflion Blush
# ../Aflion Holy Panda
# ../Aflion Iceberg Rainbow Blue
# ../Aflion Tropical Waters
# ../Agile Moon
# ../Ajazz AS Coral Pink
# ../Ajazz AS Foggy Mountain Green
# ../Ajazz AS Royal Yellow
# ../Ajazz AS Sky Blue
# ../Ajazz Brown (Clear Top, Black Bottom)
# ../Ajazz Doyu Orange
# ../Ajazz Doyu White
# ../Ajazz Purple
# ../Ajazz x Huano Banana
# ../Ajazz x Huano Peach
# ../Akko Air
# ../Akko Blue V2
# ../Akko Crystal
# ../Akko Crystal Blue
# ../Akko Crystal Silver
# ../Akko Crystal Wine Red
# ../Akko CS Jelly Black
# ../Akko CS Jelly Blue
# ../Akko CS Jelly Pink
# ../Akko CS Jelly Purple
# ../Akko CS Jelly White
# ../Akko CS Lavender Purple
# ../Akko CS Radiant Red
# ../Akko CS Sponge
# ../Akko CS Starfish
# ../Akko CS Vintage White
# ../Akko CS Wine White
# ../Akko Orange V1
# ../Akko POM Brown
# ../Akko POM Pink
# ../Akko POM Silver
# ../Akko Snow Blue Grey
# ../Akko V3 Cream Blue
# ../Akko V3 Cream Yellow
# ../Akko Wine Red
# ../All Clack
# ../AngryMiao Cyberswitch
# ../Aristotle White
# ../Asus Rog NX Blue
# ../Asus Rog NX Brown
# ../Asus Rog NX Red
# ../BBN (Tactile)
# ../BBN Linear
# ../Betty
# ../Bingsu POM
# ../Black Geon Switch
# ../Blaeck
# ../Bluejay
# ../Bobagum (62g)
# ../Bolsa Namazu
# ../Brazilian Iron
# ../BSUN Avocado Panda V2
# ../BSUN Crystal Light Blue
# ../BSUN Crystal White
# ../BSUN Dragon Fruit Panda V2
# ../BSUN Dustproof Blue
# ../BSUN Ginseng Fruit
# ../BSUN Light Switch
# ../BSUN Lychee Black
# ../BSUN Lychee Red
# ../BSUN Peach Pride
# ../BSUN Pikachu
# ../BSUN Polar Panda V2
# ../BSUN POM Panda Black
# ../BSUN POM Panda Red
# ../BSUN Racoon Panda V2
# ../BSUN Smoky Pink Tactile
# ../BSUN Yellow (Clear_White)
# ../C3 Equalz Tangerine V2 (62g)
# ../C3 Kiwi
# ../Ca Phe Sua Da
# ../Cardinal
# ../CHAOSERA Klein
# ../Cherry Blossom
# ../Cherry Hirose Clear
# ../Cherry Hirose Orange
# ../Cherry MX 'New Nixie' (Black Clear-Top)
# ../Cherry MX Black
# ../Cherry MX Blue
# ../Cherry MX Brown
# ../Cherry MX Clear
# ../Cherry MX Green
# ../Cherry MX Hyperglide Black (3 Pin)
# ../Cherry MX Hyperglide Black (5 Pin)
# ../Cherry MX Hyperglide Brown
# ../Cherry MX Jailhouse Blue
# ../Cherry MX Linear Grey
# ../Cherry MX Lock
# ../Cherry MX Red
# ../Cherry MX Tactile Grey
# ../Cherry MX White
# ../Cherry MX_M8 Black Adapter
# ../Cherry MX_M8 White Adapter
# ../Cherry Nixdorf Black
# ../Cherry Nixdorf White
# ../Chocolate Toffee Linear
# ../Chosfox x JWICK Voyager
# ../CIY Evolution Red
# ../CK x Haimu Pastel Lemon
# ../CK x Haimu Pastel Mint
# ../CK x Haimu Pastel Peach
# ../Clickiez 40g Clicky
# ../Clickiez 40g Linear
# ../Clickiez 40g Tactile
# ../Clickiez 75g Clicky
# ../Clickiez 75g Linear
# ../Clickiez 75g Tactile
# ../Commute
# ../Cookies n' Cream
# ../Corsa
# ../Cotton Candy
# ../Crow
# ../DareU Candy Pink V1
# ../DareU Sky Blue V3
# ../DareU Sky V2
# ../DareU Violet Gold Pro
# ../DareU Violet_Purple Gold V2
# ../Designer Studio Graphite Gold
# ../Designer Studio Retro Light Blue
# ../Designer Studio Retro Light Green
# ../Designer Studio Retro Light Red
# ../Designer Studio Starry
# ../Designer Studio Taoyao
# ../dk Oni
# ../Doom Tactile
# ../Durock Black Lotus (63.5g)
# ../Durock Black Lotus (80g)
# ../Durock Blush
# ../Durock POM Linear
# ../Durock Shrimp
# ../Emogogo Grey
# ../Emogogo White
# ../EMT V1
# ../EMT V2
# ../Epomaker Bluebird
# ../Epomaker Budgreigar
# ../Epomaker Comte
# ../Epomaker Flamingo
# ../Epsilon V2
# ../Feker Emerald Yellow
# ../Feker Matcha
# ../Feker White Marble
# ../Firstblood Blue
# ../Firstblood Pink
# ../FLCMMK Bauhinia
# ../FLCMMK Box Rosa Pink
# ../FLCMMK Ice Mint
# ../Forgiven
# ../G-Square Black Warrior V2
# ../G-Square Dreamland Linear
# ../G-Square Dreamland Tactile
# ../G-Square White Warrior
# ../Ganss Lunar Blue
# ../Ganss Lunar Grey
# ../Gateron Azure Dragon V2
# ../Gateron Baby Kangaroo
# ../Gateron Baby Racoon
# ../Gateron Box Ink Pink
# ../Gateron Camping
# ../Gateron Cap Crystal Blue
# ../Gateron Cap Crystal Brown
# ../Gateron Cap Crystal Red
# ../Gateron Cap Crystal Silent Red
# ../Gateron Cap Crystal Silver
# ../Gateron Cap Crystal Yellow
# ../Gateron CAP Yellow V2
# ../Gateron CJ Light Blue
# ../Gateron Cream Soda
# ../Gateron FC
# ../Gateron Holy Panda X
# ../Gateron Holy Panda X Prototype
# ../Gateron Kangaroo Ink
# ../Gateron KS9 Pro 2.0 Black
# ../Gateron KS9 Pro 2.0 Blue
# ../Gateron KS9 Pro 2.0 Brown
# ../Gateron KS9 Pro 2.0 Red
# ../Gateron KS9 Pro 2.0 Silver
# ../Gateron KS9 Pro 2.0 White
# ../Gateron KS9 Pro 2.0 Yellow
# ../Gateron Limbo
# ../Gateron Lion
# ../Gateron Mini
# ../Gateron Mink
# ../Gateron Mizu Mink
# ../Gateron North Pole
# ../Gateron Oil King
# ../Gateron Phantom Blue
# ../Gateron Phantom Red
# ../Gateron Root Beer Float
# ../Gateron Root Beer Float (New Pin)
# ../Gateron Silent Ink V2
# ../Gateron UHMknown
# ../Gateron Unicorn
# ../Gateron Vermillion Bird
# ../Gateron X
# ../Gateron x Swagkeys Pure Berry
# ../Gateron X V2
# ../Gatistotle
# ../Gazzew Phoenix Final 75g
# ../Gazzew Phoenix V1 75g
# ../Gazzew Phoenix V2 75g
# ../Glorious Fox
# ../GoPolar Yang
# ../GoPolar Yin
# ../Grain Gold Blue Linear Sample
# ../Grain Gold Neon V1
# ../Grain Gold Neon V2
# ../Grain Gold Tom Gold Pink
# ../Green Jacket Linear
# ../Green Jacket Tactile
# ../Greetech Black (Clear_White, 3 Pin)
# ../Greetech Blue (Black Housing)
# ../Greetech Blue (Clear_White, 5 Pin)
# ../Gypsophilia 1
# ../Gypsophilia 2
# ../Gypsophilia 3
# ../Gypsophilia 4
# ../Gypsophilia 5
# ../Gypsophilia 6
# ../Hades
# ../Haimu Heartbeat
# ../Haimu Whisper
# ../Haimu x Geon White
# ../Haimu x Geon Yellow
# ../HAPE Orange
# ../HCP Hirose Clear
# ../HiGround x TTC Titan Heart
# ../HK Gaming MS-1 Pro Lake Blue
# ../HK Gaming MS-1 Pro Marlin Blue
# ../HK Gaming MS-1 Pro Sky Blue
# ../Honeycomb
# ../Hoshizora
# ../Huano Dustproof Purple & Hot Pink (Grey Bottom)
# ../Huano Earth Yellow
# ../Huano Hot Pink
# ../Huano Pandora
# ../Huano Pineapple
# ../Huano Pink
# ../Huano Purple
# ../Huano Red-Orange
# ../Huano Silver
# ../Huano Spirit Wind
# ../Huano Teal
# ../Huano Turquoise
# ../Husky
# ../HyperX Aqua
# ../HyperX Blue
# ../HyperX Red
# ../In Former Days
# ../Invokeys Black Sesame
# ../Invokeys Blueberry Chiffon HDPE Prototype R1
# ../Invokeys Blueberry Chiffon Prototype R1
# ../Invokeys Blueberry Chiffon Prototype R2
# ../Invokeys Matcha Latte
# ../Invyr Holy Panda
# ../Jerrzi Black
# ../Jerrzi Blue
# ../Jerrzi Brown
# ../Jerrzi Coral
# ../Jerrzi Dustproof Clear
# ../Jerrzi Dustproof Pink
# ../Jerrzi Dustproof White
# ../Jerrzi Dustproof Yellow
# ../Jerrzi Kyria Brown
# ../Jerrzi Kyria Grey
# ../Jerrzi Kyria Pink
# ../Jerrzi Kyria Red
# ../Jerrzi Kyria White
# ../Jerrzi Kyria Yellow
# ../Jerrzi Orange
# ../Jerrzi Red
# ../Jerrzi Seashell
# ../Jerrzi Violet
# ../Jerrzi Yellow
# ../Jixian Blue
# ../JKLP Holy Panda
# ../JWICK Ginger Milk
# ../JWICK Ice White
# ../JWICK Red
# ../JWICK Semi Silent
# ../JWICK T1
# ../JWICK Taro
# ../JWICK Ultimate Black
# ../JWICK Yellow
# ../JWK Black CV1
# ../JWK Black CV2
# ../JWK Blue Lotus
# ../JWK Bluey
# ../JWK CW
# ../JWK DIE FOR ME
# ../JWK F1
# ../JWK Pink-Jade
# ../Kailh Arctic Fox
# ../Kailh Arctic Fox V2
# ../Kailh Box Ancient Grey
# ../Kailh Box Jade
# ../Kailh Box Navy
# ../Kailh Box Speed Ultimate
# ../Kailh Box Summer (Zhixia)
# ../Kailh Box V2 Brown
# ../Kailh Box V2 Red
# ../Kailh Box V2 White
# ../Kailh Chinoiserie Delo
# ../Kailh Christmas Tree
# ../Kailh Crystal Burgundy
# ../Kailh Deep Sea
# ../Kailh MX Star
# ../Kailh Pink Unicorn
# ../Kailh Pro Burgundy (PCB Mount)
# ../Kailh Pro Burgundy (Plate Mount)
# ../Kailh Pro Heavy Berry (PCB Mount)
# ../Kailh Pro Heavy Berry (Plate Mount)
# ../Kailh Pro Heavy Plum (PCB Mount)
# ../Kailh Pro Heavy Plum (Plate Mount)
# ../Kailh Pro Heavy Sage (PCB Mount)
# ../Kailh Pro Heavy Sage (Plate Mount)
# ../Kailh Pro Light Green (PCB Mount)
# ../Kailh Pro Light Green (Plate Mount)
# ../Kailh Pro Midnight Grey
# ../Kailh Pro Midnight Light Yellow
# ../Kailh Pro Purple (PCB Mount)
# ../Kailh Pro Purple (Plate Mount)
# ../Kailh Santa Hat
# ../Kailh Speed Bronze (Plate Mount)
# ../Kailh Speed Copper (PCB Mount)
# ../Kailh Speed Copper (Plate Mount)
# ../Kailh Speed Gold (PCB Mount)
# ../Kailh Speed Gold (Plate Mount)
# ../Kailh Speed Pink
# ../Kailh Speed Silver (PCB Mount)
# ../Kailh Speed Silver (Plate Mount)
# ../Kailh Sunset Tactile Choc
# ../Kailh Super Speed Red
# ../Kailh Super Speed Silver
# ../Kailh White Owl
# ../Kailh x Varmilo Prestige Blue
# ../Kailh x Varmilo Prestige Red
# ../Keychron Gateron Phantom Brown
# ../Keychron Low Profile Banana
# ../Keychron Low Profile Mint
# ../Keychron Red (Clear_Black)
# ../Keyfirst Bling Blue
# ../Keyfirst Bling Green
# ../Keyfirst Bling Purple
# ../Keyfirst Bling Red
# ../Keyfirst Bling Yellow
# ../KeyGeek Blue and Yellow Sample
# ../KeyGeek Raw
# ../KFA Lubed Pink Robin
# ../KFA N2O Laughing Gas
# ../Kinetic Labs Gecko
# ../KNC Keys Black Jacket
# ../Kono Midnight
# ../Kono Sunrise
# ../Kono Sunset
# ../KRGD Blue
# ../KRGD Brown
# ../KTT Blue Jacaranda
# ../KTT Cabbage Tofu (Opaque Top)
# ../KTT Cabbage Tofu (Transparent Top)
# ../KTT Chalk
# ../KTT Cloud Blue (New Mold)
# ../KTT Custard
# ../KTT Darling
# ../KTT Floating Light
# ../KTT Gold
# ../KTT Grey Sample
# ../KTT Iwai Tea
# ../KTT Lightning
# ../KTT Low Profile White
# ../KTT Mango Sago
# ../KTT Marble
# ../KTT Matcha (Blank Nameplate)
# ../KTT Phalaenopsis
# ../KTT Pink and Green Sample
# ../KTT Pink and Lime Green Sample
# ../KTT Pink and Pink Sample
# ../KTT Pink and White Sample
# ../KTT Pink and Yellow Sample
# ../KTT Reccazr KU Brown
# ../KTT Reccazr KU Orange
# ../KTT Soot
# ../KTT Strawberry
# ../LCET Moonlit Night
# ../LCET Sea Night
# ../LCET Wujing
# ../Lelelab Crystal
# ../Lelelab Y2K
# ../Leobog Ashwood
# ../Leobog Ashwood V2
# ../Leobog Ashwood V3
# ../Leobog Black
# ../Leobog Ice Soul
# ../Leobog Juggle
# ../Leobog Juggle V2
# ../Leobog Kayking
# ../Leobog Leek_Chive
# ../Leobog Nimbus
# ../Leobog Nimbus V2
# ../Leobog Standard Brown
# ../Leobog Wolfberry
# ../Leobog Yiling
# ../Lichicx Green Mustard
# ../LICHICX Lucy
# ../Lubed Black Geon Switch
# ../Lubed Clear Geon Switch
# ../Lubed Invokeys Blueberry Chiffon
# ../Malvix Studio Irene
# ../Mamba
# ../Matcha Bamboo Shoot
# ../Meirun Orange Sample
# ../Meirun Red Sample
# ../Mekanisk Ultramarine V2
# ../Mint Chocolate Chip POM
# ../MMD 'Ice'
# ../MMD 'Strawberry'
# ../MMD Green and Grey Linear
# ../MMD Green Tactile
# ../MMD Honey Tactile POM
# ../MMD Matcha Ice Cream
# ../MOD-H Linear
# ../MOD-H Tactile
# ../MOD-L Linear
# ../MOD-L Tactile
# ../MOD-M Linear
# ../MOD-M Tactile
# ../MOD-SH
# ../MODE Anthracite
# ../MODE Anthracite Prototype
# ../MODE Obscura
# ../MODE Obscura Prototype
# ../MODE Reflex
# ../MODE Signal
# ../MODE Tomorrow Blue
# ../MODE Tomorrow Blue Prototype
# ../MODE Tomorrow Green
# ../MODE Tomorrow Green Prototype
# ../MODE Tomorrow Orange
# ../MODE Tomorrow Orange Prototype
# ../MODE Tomorrow Purple
# ../MODE Tomorrow Purple Prototype
# ../MODE Tomorrow Yellow
# ../MODE Tomorrow Yellow Prototype
# ../Momoka Frog V3
# ../Momoka Shark
# ../Moondrop x G-Square Lunalight
# ../Moondrop x G-Square Tessence
# ../Moyu Pansy
# ../Moyu Studio Ice Matcha
# ../Musetsu
# ../Naevy V2
# ../Neapolitan Ice Cream
# ../Next Time Blue Star
# ../NextTime Engine V3
# ../NextTime Watermelon Pro
# ../Nightingale Lubed
# ../Nightingale Unlubed
# ../NK Silk Awaken Green
# ../NK Silk Awaken Pink
# ../NK Silk Mictlan Blue
# ../NK Silk Mictlan Orange
# ../NK Silk Mictlan Pink
# ../NK Silk Mictlan Purple
# ../NK Silk Mictlan Yellow
# ../NK TFUE Silk
# ../Novelkeys Box Cream
# ../Novelkeys Cream
# ../Novelkeys Cream Arc
# ../Novelkeys Cream Arc Inverted Spring
# ../Novelkeys Cream Clickie
# ../Novelkeys Cream Tactile
# ../Novelkeys Cream+
# ../Novelkeys Cream+ (Copper Insert)
# ../Novelkeys Cream+ (Silicone Insert Proto)
# ../Novelkeys Cream+ (Titanium Insert)
# ../Novelkeys Dream Cream
# ../Novelkeys Launch Cream
# ../Novelkeys Sherbet
# ../OArmy Green
# ../Obsidian L
# ../Obsidian Pro
# ../Obsidian Pro V2
# ../Oooolong
# ../Opblack
# ../Outemu Bai Lan
# ../Outemu Cream Top Milk Green
# ../Outemu Cream Top Milk Peach
# ../Outemu Cream Top Milk Tea
# ../Outemu Jerry
# ../Outemu Milk Green
# ../Outemu Milk Peach
# ../Outemu Milk Tea
# ../Outemu Ocean Silent Dustproof Linear
# ../Outemu Ocean Silent Linear
# ../Outemu Tom
# ../Owlabs Neon
# ../Oxford Micro Orange
# ../Penguin (Lubed)
# ../Philikeys Pink
# ../Philikeys White
# ../Pink 43Studio Prototype
# ../Polycarbonate over Nylon Invokeys Matcha Latte V2 Prototype
# ../Popcorn
# ../Popu
# ../Prevail Key Co Nebula
# ../ProWorld Clicky
# ../PunkShoo Melody Factory Error
# ../Qeeke Mica
# ../Quartz V2
# ../Raed V2
# ../RAMA WORKS Duck
# ../RAMA WORKS Duck Sample 1
# ../RAMA WORKS Duck Sample 2
# ../Red Jacket
# ../Redragon Panda
# ../Redragon Sapphire
# ../Redragon Thin Lemon
# ../RK Celadon
# ../RK Golden Purple
# ../RK Latte
# ../RK Sakura
# ../RK Sea Blue
# ../RK White
# ../Rococo Tactile
# ../Rubrehose Brown
# ../Rubrehose Grey
# ../S1 Peaches
# ../Safety
# ../Sakurio
# ../Saybour Optical Blue
# ../Silent Alpaca
# ../Silent Blue Macaw
# ../Silent Coral
# ../Skyloong Brown Iceberg
# ../Skyloong Pink Iceberg
# ../Skyloong Red Iceberg
# ../Skyloong Silent Brown Iceberg
# ../Skyloong Silent Pink Iceberg
# ../Skyloong Silent Red Iceberg
# ../Skyloong Silent Silver Iceberg
# ../Skyloong Silent White Iceberg
# ../Skyloong Silent Yellow Iceberg
# ../Skyloong Silver Iceberg
# ../Skyloong White Iceberg
# ../Skyloong Yellow Iceberg
# ../SOTC
# ../SP Star Meteor Grey (Grey Housing)
# ../SP Star Meteor Orange (Grey Housing)
# ../SP Star Meteor Purple (Grey Housing)
# ../SP Star Meteor White (Grey Housing)
# ../SP Star Sacramento
# ../Splash Brothers
# ../Strawberry Jelly V4
# ../Strawberry Milk Ice Linear
# ../Strawberry Milk Ice Tactile
# ../Sunny Side Up Linear
# ../Swagkeys Bubble
# ../Swirl Red
# ../Tamago Sushi
# ../Tealio V2
# ../TeamWolf Black
# ../TeamWolf Blue
# ../TeamWolf Optical Green 4.0
# ../TeamWolf Optical Tan 2.0
# ../TeamWolf Optical Tan 4.0
# ../TeamWolf Red
# ../TeamWolf x Manic Red
# ../Techno Violet V1
# ../Tecsee Coral
# ../Tecsee Ice Milk Tactile
# ../Tecsee Lake Blue
# ../Tecsee Middle Switch Linear
# ../Tecsee Middle Switch Tactile
# ../Tecsee Sky Blue Cloud Linear
# ../Tecsee Sky Blue Cloud Tactile
# ../Tecsee Strawberry Ice
# ../Teton Cream
# ../TKC Blackberry
# ../TofuTypes x KNC Keys Tofu
# ../Toy Brick
# ../Transmit (52g)
# ../Transmit (62g)
# ../Transmit Garage Kit
# ../Transmit Green (42g)
# ../Transmit Iced Tea
# ../Transmit Small Iceberg
# ../Transmit Toy
# ../Trash Linear
# ../Tropical Water V2
# ../TTC Ace V1.5
# ../TTC Ace V2
# ../TTC Bluish White (Full Silent)
# ../TTC Chaotic Panda
# ../TTC Cloud V2
# ../TTC Cyber Panda
# ../TTC Flame Purple
# ../TTC Flame Red Half Height LED
# ../TTC Frozen V2
# ../TTC Gold Brown Pro
# ../TTC Gold Red Pro
# ../TTC Gold Silver Pro
# ../TTC K Series Black
# ../TTC K Series Blue
# ../TTC K Series Brown
# ../TTC K Series Red
# ../TTC Love
# ../TTC Matrix 01 Linear
# ../TTC Matrix 01 Tactile
# ../TTC MT Blue
# ../TTC MT Red
# ../TTC NCR V2
# ../TTC Neptune
# ../TTC Old School
# ../TTC Orange V2 Brown
# ../TTC Orange V2 Red
# ../TTC Razer Dustproof Green
# ../TTC Razer Dustproof Orange
# ../TTC Razer Dustproof Yellow
# ../TTC Silent Red V2
# ../TTC Speed Silver
# ../TTC Tiger
# ../TTC Venus
# ../TTC Wild (42g)
# ../TTC Wild (55g)
# ../TTC x Varmilo Speed Gold
# ../TTC Yellow Top Brown
# ../TTC Yellow Top Brown (Lightbar)
# ../U4TX Plum
# ../Ube Crinkle Cookie
# ../Unlabeled Invokeys Matcha Latte V2 Prototype
# ../Unlubed Invokeys Blueberry Chiffon
# ../Varmilo EC V2 Iris
# ../Varmilo EC V2 Jasmine
# ../Varmilo EC V2 Moxa
# ../Varmilo EC V2 Orange
# ../Varmilo EC V2 Violet
# ../Whale Works x Illusion Illusion
# ../Wooting Lekker
# ../WS Aurora Pink
# ../WS Onion
# ../Wuque Studio Dustproof Grey
# ../Wuque Studio Dustproof White
# ../Wuque Studio Morandi
# ../YOK EMT V1
# ../Zaku (Nameplate)
# ../Zealio V1 Redux 62g
# ../Zealio V2 AC (62g)
# ../Zealio V2 AC (78g)
# ../Zepsody Bluebonnet
# ../Zorro Black (White Bottom)
# ../Zorro Blue (White Bottom)
# ../Zorro Brown (White Bottom)
# ../Zorro Red (White Bottom)
